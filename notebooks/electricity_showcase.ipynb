# %% [markdown]
# Electricity showcase for basic PULPO
#
# Written by Fabian Lechtenberg, 18.09.2023
#
# Last Update: 23.09.2023

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">(1) Selection of LCI Data</h2>
# </div>

# %% [markdown]
# ### Import section

# %% [markdown]
# In this working version of the pulpo repository, pulpo musst be imported from the folder above, which can be done by appending ".." to the system path. Later, only the import after installation via pip will be necessary.

# %%
import os
import sys
sys.path.append('../')
from pulpo import pulpo

import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Setup

# %% [markdown]
# Specify the project, database and method to be used. Also indicate the folder where the working data should be stored. For this example to work, you need a project "**pulpo**" with a database "**cutoff38**", which is the ecoinvent 3.8 cutoff system model.

# %%
project = "pulpo"
database = "cutoff38"
methods = "('IPCC 2013', 'climate change', 'GWP 100a')"

# Substitute with your working directory of choice
notebook_dir = os.path.dirname(os.getcwd())
directory = os.path.join(notebook_dir, 'data')

# Substitute with your GAMS path
GAMS_PATH = "C:/GAMS/37/gams.exe"

# %% [markdown]
# Create a pulpo object called "pulpo_worker". This object is an element of the class "PulpoOptimizer", a class that links the different utilitiy modules containing code for retrieving, preparing and adjusting the data, preparing and running the optimization problem, as well as saving the results.

# %%
pulpo_worker = pulpo.PulpoOptimizer(project, database, methods, directory)

# %% [markdown]
# Retrieve the data. If data is already loaded, this step is automatically skipped.

# %%
pulpo_worker.get_lci_data()

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">(2) User Specifications</h2>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="pictures/electricity_showcase_1.png" alt="Image Alt Text" style="width: 50%;" />
# </div>

# %% [markdown]
# ### Specify the **functional unit**

# %% [markdown]
# Retrieve the market activity for liquid hydrogen in Europe (RER). Use the function "**<span style="color: red;">retrieve_activities</span>**" for this purpose. The function takes 4 optional arguments: "keys" (🔑) --> "activities" (⚙️) --> "reference_products" (📦) --> "locations" (🗺️). The activities are retrieved by this order.
#
# Since the key is unique, a single activity for each passed key will be returned. Activity names, reference_prduct and locations are not unique, so the best match for the passed data will be returned.

# %% [markdown]
# #### Passing keys  🔑

# %% [markdown]
# Keys can be obtained e.g. directly from **activity browser** and several keys can be passed at the same time.

# %%
keys = ["('cutoff38', '962727b9a36bcaa186f222b29b57f6a3')", "('cutoff38', '473d4bb488e8f903b58203f3e5161636')"]

# %%
pulpo_worker.retrieve_activities(keys=keys)
# Out:
# ['market for electricity, high voltage' (kilowatt hour, ES, None),
#  'market for electricity, high voltage' (kilowatt hour, DE, None)]

# %% [markdown]
# #### Passing activity  name (⚙️), reference_product (📦) and/or location (🗺️)

# %% [markdown]
# Instead of passing the keys, a combination of activities, reference_products and locations can be passed. A best match (all existing combinations) will be returned.

# %%
activities = ["market for electricity, high voltage"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

# %% [markdown]
# It is also possible to pass only partial information such as only reference product or only activity name:

# %%
pulpo_worker.retrieve_activities(activities=activities)
# Out:
# ['market for electricity, high voltage' (kilowatt hour, CA-NF, None),
#  'market for electricity, high voltage' (kilowatt hour, US-HICC, None),
#  'market for electricity, high voltage' (kilowatt hour, BG, None),
#  'market for electricity, high voltage' (kilowatt hour, HN, None),
#  'market for electricity, high voltage' (kilowatt hour, IL, None),
#  'market for electricity, high voltage' (kilowatt hour, JP, None),
#  'market for electricity, high voltage' (kilowatt hour, AE, None),
#  'market for electricity, high voltage' (kilowatt hour, ER, None),
#  'market for electricity, high voltage' (kilowatt hour, KE, None),
#  'market for electricity, high voltage' (kilowatt hour, UA, None),
#  'market for electricity, high voltage' (kilowatt hour, HK, None),
#  'market for electricity, high voltage' (kilowatt hour, TR, None),
#  'market for electricity, high voltage' (kilowatt hour, BO, None),
#  'market for electricity, high voltage' (kilowatt hour, CY, None),
#  'market for electricity, high voltage' (kilowatt hour, AR, None),
#  'market for electricity, high voltage' (kilowatt hour, CZ, None),
#  'market for electricity, high voltage' (kilowatt hour, SE, None),
#  'market for electricity, high voltage' (kilowatt hour, ZA, None),
#  'market for electricity, high voltage' (kilowatt hour, QA, None),
#  'market for electricity, high voltage' (kilowatt hour, SK, None),
#  'market for electricity, high voltage' (kilowatt hour, KG, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-NU, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-ON, None),
#  'market for electricity, high voltage' (kilowatt hour, NG, None),
#  'market for electricity, high voltage' (kilowatt hour, AT, None),
#  'market for electricity, high voltage' (kilowatt hour, PH, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-YK, None),
#  'market for electricity, high voltage' (kilowatt hour, US-SERC, None),
#  'market for electricity, high voltage' (kilowatt hour, LB, None),
#  'market for electricity, high voltage' (kilowatt hour, CW, None),
#  'market for electricity, high voltage' (kilowatt hour, NA, None),
#  'market for electricity, high voltage' (kilowatt hour, PT, None),
#  'market for electricity, high voltage' (kilowatt hour, ID, None),
#  'market for electricity, high voltage' (kilowatt hour, FR, None),
#  'market for electricity, high voltage' (kilowatt hour, TT, None),
#  'market for electricity, high voltage' (kilowatt hour, CD, None),
#  'market for electricity, high voltage' (kilowatt hour, BY, None),
#  'market for electricity, high voltage' (kilowatt hour, SI, None),
#  'market for electricity, high voltage' (kilowatt hour, IR, None),
#  'market for electricity, high voltage' (kilowatt hour, ME, None),
#  'market for electricity, high voltage' (kilowatt hour, UZ, None),
#  'market for electricity, high voltage' (kilowatt hour, LU, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-QC, None),
#  'market for electricity, high voltage' (kilowatt hour, TW, None),
#  'market for electricity, high voltage' (kilowatt hour, GR, None),
#  'market for electricity, high voltage' (kilowatt hour, US-TRE, None),
#  'market for electricity, high voltage' (kilowatt hour, BH, None),
#  'market for electricity, high voltage' (kilowatt hour, FI, None),
#  'market for electricity, high voltage' (kilowatt hour, US-NPCC, None),
#  'market for electricity, high voltage' (kilowatt hour, CH, None),
#  'market for electricity, high voltage' (kilowatt hour, TZ, None),
#  'market for electricity, high voltage' (kilowatt hour, DK, None),
#  'market for electricity, high voltage' (kilowatt hour, JO, None),
#  'market for electricity, high voltage' (kilowatt hour, US-MRO, None),
#  'market for electricity, high voltage' (kilowatt hour, IE, None),
#  'market for electricity, high voltage' (kilowatt hour, US-RFC, None),
#  'market for electricity, high voltage' (kilowatt hour, DE, None),
#  'market for electricity, high voltage' (kilowatt hour, UY, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-PE, None),
#  'market for electricity, high voltage' (kilowatt hour, OM, None),
#  'market for electricity, high voltage' (kilowatt hour, MZ, None),
#  'market for electricity, high voltage' (kilowatt hour, SS, None),
#  'market for electricity, high voltage' (kilowatt hour, PE, None),
#  'market for electricity, high voltage' (kilowatt hour, BR-North-eastern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, VN, None),
#  'market for electricity, high voltage' (kilowatt hour, BR-Southern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, GT, None),
#  'market for electricity, high voltage' (kilowatt hour, XK, None),
#  'market for electricity, high voltage' (kilowatt hour, BR-Northern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-SK, None),
#  'market for electricity, high voltage' (kilowatt hour, NO, None),
#  'market for electricity, high voltage' (kilowatt hour, EG, None),
#  'market for electricity, high voltage' (kilowatt hour, CN-CSG, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-Western grid, None),
#  'market for electricity, high voltage' (kilowatt hour, MX, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-NT, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-Northern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, KH, None),
#  'market for electricity, high voltage' (kilowatt hour, AO, None),
#  'market for electricity, high voltage' (kilowatt hour, CL, None),
#  'market for electricity, high voltage' (kilowatt hour, VE, None),
#  'market for electricity, high voltage' (kilowatt hour, LT, None),
#  'market for electricity, high voltage' (kilowatt hour, SG, None),
#  'market for electricity, high voltage' (kilowatt hour, AL, None),
#  'market for electricity, high voltage' (kilowatt hour, US-WECC, None),
#  'market for electricity, high voltage' (kilowatt hour, US-PR, None),
#  'market for electricity, high voltage' (kilowatt hour, CG, None),
#  'market for electricity, high voltage' (kilowatt hour, AU, None),
#  'market for electricity, high voltage' (kilowatt hour, IQ, None),
#  'market for electricity, high voltage' (kilowatt hour, KP, None),
#  'market for electricity, high voltage' (kilowatt hour, SD, None),
#  'market for electricity, high voltage' (kilowatt hour, HR, None),
#  'market for electricity, high voltage' (kilowatt hour, JM, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-AB, None),
#  'market for electricity, high voltage' (kilowatt hour, BD, None),
#  'market for electricity, high voltage' (kilowatt hour, SV, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-North-eastern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, TH, None),
#  'market for electricity, high voltage' (kilowatt hour, BW, None),
#  'market for electricity, high voltage' (kilowatt hour, NI, None),
#  'market for electricity, high voltage' (kilowatt hour, CO, None),
#  'market for electricity, high voltage' (kilowatt hour, PL, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-NB, None),
#  'market for electricity, high voltage' (kilowatt hour, SY, None),
#  'market for electricity, high voltage' (kilowatt hour, AZ, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-Eastern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, PY, None),
#  'market for electricity, high voltage' (kilowatt hour, PA, None),
#  'market for electricity, high voltage' (kilowatt hour, BN, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-MB, None),
#  'market for electricity, high voltage' (kilowatt hour, MM, None),
#  'market for electricity, high voltage' (kilowatt hour, GA, None),
#  'market for electricity, high voltage' (kilowatt hour, IT, None),
#  'market for electricity, high voltage' (kilowatt hour, CM, None),
#  'market for electricity, high voltage' (kilowatt hour, LK, None),
#  'market for electricity, high voltage' (kilowatt hour, NL, None),
#  'market for electricity, high voltage' (kilowatt hour, RS, None),
#  'market for electricity, high voltage' (kilowatt hour, GH, None),
#  'market for electricity, high voltage' (kilowatt hour, CN-SGCC, None),
#  'market for electricity, high voltage' (kilowatt hour, AM, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-Southern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, IS, None),
#  'market for electricity, high voltage' (kilowatt hour, NZ, None),
#  'market for electricity, high voltage' (kilowatt hour, HU, None),
#  'market for electricity, high voltage' (kilowatt hour, EE, None),
#  'market for electricity, high voltage' (kilowatt hour, MD, None),
#  'market for electricity, high voltage' (kilowatt hour, KZ, None),
#  'market for electricity, high voltage' (kilowatt hour, GB, None),
#  'market for electricity, high voltage' (kilowatt hour, DO, None),
#  'market for electricity, high voltage' (kilowatt hour, HT, None),
#  'market for electricity, high voltage' (kilowatt hour, TG, None),
#  'market for electricity, high voltage' (kilowatt hour, BA, None),
#  'market for electricity, high voltage' (kilowatt hour, GE, None),
#  'market for electricity, high voltage' (kilowatt hour, ET, None),
#  'market for electricity, high voltage' (kilowatt hour, LY, None),
#  'market for electricity, high voltage' (kilowatt hour, ES, None),
#  'market for electricity, high voltage' (kilowatt hour, SN, None),
#  'market for electricity, high voltage' (kilowatt hour, ZM, None),
#  'market for electricity, high voltage' (kilowatt hour, ZW, None),
#  'market for electricity, high voltage' (kilowatt hour, KW, None),
#  'market for electricity, high voltage' (kilowatt hour, EC, None),
#  'market for electricity, high voltage' (kilowatt hour, BE, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-BC, None),
#  'market for electricity, high voltage' (kilowatt hour, RO, None),
#  'market for electricity, high voltage' (kilowatt hour, BJ, None),
#  'market for electricity, high voltage' (kilowatt hour, MY, None),
#  'market for electricity, high voltage' (kilowatt hour, MA, None),
#  'market for electricity, high voltage' (kilowatt hour, DZ, None),
#  'market for electricity, high voltage' (kilowatt hour, TN, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-NS, None),
#  'market for electricity, high voltage' (kilowatt hour, RU, None),
#  'market for electricity, high voltage' (kilowatt hour, MK, None),
#  'market for electricity, high voltage' (kilowatt hour, US-ASCC, None),
#  'market for electricity, high voltage' (kilowatt hour, PK, None),
#  'market for electricity, high voltage' (kilowatt hour, MU, None),
#  'market for electricity, high voltage' (kilowatt hour, KR, None),
#  'market for electricity, high voltage' (kilowatt hour, LV, None),
#  'market for electricity, high voltage' (kilowatt hour, CU, None),
#  'market for electricity, high voltage' (kilowatt hour, BR-South-eastern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, MT, None),
#  'market for electricity, high voltage' (kilowatt hour, CI, None),
#  'market for electricity, high voltage' (kilowatt hour, SA, None),
#  'market for electricity, high voltage' (kilowatt hour, MN, None),
#  'market for electricity, high voltage' (kilowatt hour, GI, None),
#  'market for electricity, high voltage' (kilowatt hour, CR, None),
#  'market for electricity, high voltage' (kilowatt hour, YE, None),
#  'market for electricity, high voltage' (kilowatt hour, NE, None),
#  'market for electricity, high voltage' (kilowatt hour, BR-Mid-western grid, None),
#  'market for electricity, high voltage' (kilowatt hour, NP, None),
#  'market for electricity, high voltage' (kilowatt hour, TM, None),
#  'market for electricity, high voltage' (kilowatt hour, TJ, None)]

# %%
pulpo_worker.retrieve_activities(reference_products=reference_products)
# Out:
# ['electricity production, hard coal' (kilowatt hour, US-ASCC, None),
#  'market for electricity, high voltage' (kilowatt hour, RU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-ASCC, None),
#  'heat and power co-generation, natural gas, 1MW electrical, lean burn' (kilowatt hour, RoW, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, LV, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, BA, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, US-SERC, None),
#  'electricity production, natural gas, 10MW' (kilowatt hour, DE, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-MB, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, HR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CA-MB, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, US-WECC, None),
#  'electricity production, hard coal' (kilowatt hour, RoW, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-BC, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, KR, None),
#  'electricity, high voltage, import from EE' (kilowatt hour, LV, None),
#  'electricity, high voltage, import from RU' (kilowatt hour, BY, None),
#  'electricity production, hydro, reservoir, tropical region' (kilowatt hour, CO, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-PB, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, NL, None),
#  'electricity, high voltage, production mix' (kilowatt hour, MX, None),
#  'electricity production, lignite' (kilowatt hour, ID, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-RJ, None),
#  'market for electricity, high voltage' (kilowatt hour, KZ, None),
#  'electricity production, hard coal' (kilowatt hour, CN-NX, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, PT, None),
#  'electricity, high voltage, import from PL' (kilowatt hour, LT, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CA-YK, None),
#  'electricity production, oil' (kilowatt hour, CN-HE, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, CH, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, ZA, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-SH, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-GJ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, SI, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-ZJ, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, ZA, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, US-WECC, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, FR, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, GB, None),
#  'electricity production, oil' (kilowatt hour, CN-ZJ, None),
#  'electricity production, hard coal' (kilowatt hour, CN-SC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, BE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, DE, None),
#  'heat and power co-generation, oil' (kilowatt hour, US-SERC, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, JP, None),
#  'market for electricity, high voltage' (kilowatt hour, AM, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, US-WECC, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-KL, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-GZ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-ZJ, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-SC, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CL, None),
#  'market for electricity, high voltage' (kilowatt hour, SE, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, US-NPCC, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-SC, None),
#  'electricity production, natural gas, 10MW' (kilowatt hour, NL, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, HR, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, RS, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-AH, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, TW, None),
#  'electricity, high voltage, import from RU' (kilowatt hour, LT, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-FJ, None),
#  'electricity production, hard coal' (kilowatt hour, CN-HB, None),
#  'electricity production, compressed air energy storage, adiabatic' (kilowatt hour, RoW, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, LU, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-HP, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, CY, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, DE, None),
#  'heat and power co-generation, lignite' (kilowatt hour, PL, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HB, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CY, None),
#  'market for electricity, high voltage' (kilowatt hour, CG, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, JP, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-AP, None),
#  'electricity, high voltage, import from GH' (kilowatt hour, TG, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CH, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, TW, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, BG, None),
#  'heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014' (kilowatt hour, CH, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, CN-GD, None),
#  'electricity, high voltage, import from IN-Western grid' (kilowatt hour, IN-Southern grid, None),
#  'electricity, high voltage, import from HR' (kilowatt hour, BA, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, NO, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, HU, None),
#  'electricity production, oil' (kilowatt hour, CN-XJ, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, RS, None),
#  'electricity, high voltage, import from DK' (kilowatt hour, NO, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, ES, None),
#  'market for electricity, high voltage' (kilowatt hour, AE, None),
#  'market group for electricity, high voltage' (kilowatt hour, GLO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, AT, None),
#  'market for electricity, high voltage' (kilowatt hour, RS, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-SK, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, US-WECC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-TN, None),
#  'electricity, high voltage, production mix' (kilowatt hour, YE, None),
#  'electricity, high voltage, import from BA' (kilowatt hour, RS, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, SE, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-TN, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, ZA, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, RU, None),
#  'market for electricity, high voltage' (kilowatt hour, US-NPCC, None),
#  'electricity, high voltage, import from PT' (kilowatt hour, ES, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, AT, None),
#  'electricity, high voltage, import from NO' (kilowatt hour, NL, None),
#  'electricity production, hard coal' (kilowatt hour, PE, None),
#  'electricity production, hard coal' (kilowatt hour, CL, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, US-ASCC, None),
#  'market group for electricity, high voltage' (kilowatt hour, US, None),
#  'electricity production, peat' (kilowatt hour, IE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-NB, None),
#  'electricity, high voltage, import from ES' (kilowatt hour, FR, None),
#  'electricity production, deep geothermal' (kilowatt hour, RoW, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, FI, None),
#  'electricity, high voltage, import from TR' (kilowatt hour, SY, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-ZJ, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, ES, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, US-RFC, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-HN, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, LV, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-MB, None),
#  'electricity production, hard coal' (kilowatt hour, CZ, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-SC, None),
#  'electricity production, solar thermal parabolic trough, 50 MW' (kilowatt hour, US-WECC, None),
#  'electricity, high voltage, import from IN-Northern grid' (kilowatt hour, NP, None),
#  'electricity, high voltage, production mix' (kilowatt hour, LK, None),
#  'market for electricity, high voltage' (kilowatt hour, CM, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, NP, None),
#  'market for electricity, high voltage' (kilowatt hour, ME, None),
#  'electricity production, compressed air energy storage' (kilowatt hour, RoW, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-LN, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-HU, None),
#  'heat and power co-generation, oil' (kilowatt hour, HU, None),
#  'heat and power co-generation, diesel, 200kW electrical, SCR-NOx reduction' (kilowatt hour, RoW, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, HR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-TR, None),
#  'electricity production, lignite' (kilowatt hour, US-HICC, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, EE, None),
#  'electricity, high voltage, import from SY' (kilowatt hour, LB, None),
#  'electricity, high voltage, production mix' (kilowatt hour, KE, None),
#  'market for electricity, high voltage' (kilowatt hour, DZ, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-AH, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, ES, None),
#  'electricity, high voltage, import from DZ' (kilowatt hour, TN, None),
#  'electricity production, oil' (kilowatt hour, UA, None),
#  'electricity, high voltage, production mix' (kilowatt hour, JM, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-SC, None),
#  'market for electricity, high voltage' (kilowatt hour, HK, None),
#  'electricity, high voltage, import from TG' (kilowatt hour, GH, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, RO, None),
#  'electricity, high voltage, import from UZ' (kilowatt hour, RU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-HB, None),
#  'electricity, high voltage, import from CA-QC' (kilowatt hour, CA-NB, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CA-ON, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CD, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-NX, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, BA, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, BR-South-eastern grid, None),
#  'heat and power co-generation, natural gas, 500kW electrical, lean burn' (kilowatt hour, RoW, None),
#  'market for electricity, high voltage' (kilowatt hour, YE, None),
#  'market for electricity, high voltage' (kilowatt hour, NG, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-SA, None),
#  'electricity, high voltage, import from MK' (kilowatt hour, BG, None),
#  'electricity production, lignite' (kilowatt hour, CA-NS, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, BA, None),
#  'electricity, high voltage, import from TN' (kilowatt hour, LY, None),
#  'electricity, high voltage, import from FR' (kilowatt hour, DE, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, LU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, ME, None),
#  'electricity, high voltage, import from FR' (kilowatt hour, GB, None),
#  'electricity production, oil' (kilowatt hour, BA, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, BE, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-SX, None),
#  'electricity, high voltage, production mix' (kilowatt hour, BO, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, RU, None),
#  'electricity, high voltage, import from ID' (kilowatt hour, MY, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, IN-TN, None),
#  'electricity production, lignite' (kilowatt hour, RU, None),
#  'electricity production, deep geothermal' (kilowatt hour, IN-TN, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-NB, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, US-WECC, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-HE, None),
#  'market for electricity, high voltage' (kilowatt hour, BY, None),
#  'electricity production, oil' (kilowatt hour, AU, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, TH, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-SA, None),
#  'electricity production, oil' (kilowatt hour, CN-CQ, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, FR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-PE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, ZM, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-LN, None),
#  'electricity, high voltage, import from NO' (kilowatt hour, SE, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, KR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, GB, None),
#  'heat and power co-generation, lignite' (kilowatt hour, SI, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, ID, None),
#  'electricity, high voltage, import from DK' (kilowatt hour, DE, None),
#  'electricity production, hard coal' (kilowatt hour, CN-HE, None),
#  'electricity, high voltage, import from CZ' (kilowatt hour, PL, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, PL, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-ZJ, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-UP, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-SX, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, CZ, None),
#  'electricity, high voltage, import from LT' (kilowatt hour, LV, None),
#  'electricity, high voltage, import from US-MRO' (kilowatt hour, CA-SK, None),
#  'electricity production, oil' (kilowatt hour, CN-FJ, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, TW, None),
#  'electricity, high voltage, import from MY' (kilowatt hour, ID, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, FR, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, FI, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, IT, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-SK, None),
#  'electricity, high voltage, import from CN-CSG' (kilowatt hour, HK, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BE, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, GR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, MT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, ZA, None),
#  'electricity, high voltage, import from HR' (kilowatt hour, SI, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-JS, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, US-RFC, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, RU, None),
#  'electricity, high voltage, hydro, import from CA-NF' (kilowatt hour, CA-QC, None),
#  'petroleum refinery operation' (kilowatt hour, CH, None),
#  'electricity, high voltage, production mix' (kilowatt hour, NG, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, TZ, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, KR, None),
#  'sulfate pulp production, from softwood, unbleached' (kilowatt hour, RoW, None),
#  'electricity production, hard coal' (kilowatt hour, BE, None),
#  'ethanol production from wood' (kilowatt hour, CH, None),
#  'market for electricity, high voltage' (kilowatt hour, ER, None),
#  'electricity, high voltage, import from CA-BC' (kilowatt hour, CA-AB, None),
#  'electricity production, lignite' (kilowatt hour, CA-ON, None),
#  'electricity, high voltage, import from UA' (kilowatt hour, HU, None),
#  'market for electricity, high voltage' (kilowatt hour, MM, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-FJ, None),
#  'electricity production, nuclear, pressure water reactor, heavy water moderated' (kilowatt hour, CN-ZJ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, RO, None),
#  'electricity production, hard coal' (kilowatt hour, AR, None),
#  'electricity production, deep geothermal' (kilowatt hour, HU, None),
#  'electricity, high voltage, import from CA-NB' (kilowatt hour, CA-NS, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, CA-BC, None),
#  'electricity production, lignite' (kilowatt hour, HU, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, AT, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, HR, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, SK, None),
#  'electricity, high voltage, production mix' (kilowatt hour, BN, None),
#  'market for electricity, high voltage' (kilowatt hour, KG, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-NX, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CA-QC, None),
#  'electricity production, hard coal' (kilowatt hour, CN-HA, None),
#  'electricity production, oil' (kilowatt hour, SA, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CO, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-MH, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, US-RFC, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-NM, None),
#  'heat and power co-generation, oil' (kilowatt hour, SK, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, US-WECC, None),
#  'sulfate pulp production, from hardwood, bleached' (kilowatt hour, RoW, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, CN-GD, None),
#  'electricity, high voltage, import from IN-Northern grid' (kilowatt hour, IN-North-eastern grid, None),
#  'electricity, high voltage, import from HU' (kilowatt hour, AT, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, AR, None),
#  'electricity, high voltage, import from IN-Eastern grid' (kilowatt hour, IN-Western grid, None),
#  'electricity production, hard coal' (kilowatt hour, PT, None),
#  'electricity production, lignite' (kilowatt hour, IN-GJ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-WECC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GZ, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, RoW, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, JP, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, HU, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, IT, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, RO, None),
#  'electricity, high voltage, import from GE' (kilowatt hour, TR, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, US-NPCC, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, PT, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, HU, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, MK, None),
#  'heat and power co-generation, lignite' (kilowatt hour, DE, None),
#  'electricity, high voltage, import from GE' (kilowatt hour, AZ, None),
#  'electricity, high voltage, import from NO' (kilowatt hour, DK, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, AR, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-GJ, None),
#  'electricity, high voltage, import from BG' (kilowatt hour, RO, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-SERC, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, MX, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-JL, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, US-SERC, None),
#  'electricity, high voltage, production mix' (kilowatt hour, DK, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, LV, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-GX, None),
#  'market for electricity, high voltage' (kilowatt hour, IN-Northern grid, None),
#  'heat and power co-generation, oil' (kilowatt hour, AU, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-JL, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, US-TRE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, RoW, None),
#  'electricity production, deep geothermal' (kilowatt hour, PL, None),
#  'electricity production, oil' (kilowatt hour, CN-SA, None),
#  'electricity production, oil' (kilowatt hour, IN-KL, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, TR, None),
#  'electricity production, oil' (kilowatt hour, CN-HN, None),
#  'electricity production, oil' (kilowatt hour, PT, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-SA, None),
#  'electricity production, oil' (kilowatt hour, BG, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, IR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-QH, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, EE, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, NL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-SA, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-GD, None),
#  'market for electricity, high voltage' (kilowatt hour, QA, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CA-NT, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, LU, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, FR, None),
#  'electricity, high voltage, import from AT' (kilowatt hour, DE, None),
#  'electricity, high voltage, import from FI' (kilowatt hour, EE, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-CQ, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, SK, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, US-HICC, None),
#  'treatment of bagasse, from sugarcane, in heat and power co-generation unit, 6400kW thermal' (kilowatt hour, CO, None),
#  'electricity production, oil' (kilowatt hour, CL, None),
#  'electricity production, oil' (kilowatt hour, BR-South-eastern grid, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, CY, None),
#  'electricity production, nuclear, pressure water reactor, heavy water moderated' (kilowatt hour, AR, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, SE, None),
#  'heat and power co-generation, lignite' (kilowatt hour, TR, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DK, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, TW, None),
#  'electricity production, lignite' (kilowatt hour, IT, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-UT, None),
#  'electricity, high voltage, import from TR' (kilowatt hour, IR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-XZ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-HICC, None),
#  'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, US-SERC, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, FI, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-ASCC, None),
#  'electricity production, oil' (kilowatt hour, CN-BJ, None),
#  'electricity, high voltage, import from UZ' (kilowatt hour, KG, None),
#  'electricity, high voltage, import from RS' (kilowatt hour, MK, None),
#  'market for electricity, high voltage' (kilowatt hour, CU, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, IE, None),
#  'electricity, high voltage, import from ME' (kilowatt hour, RS, None),
#  'electricity, high voltage, import from VN' (kilowatt hour, KH, None),
#  'electricity, high voltage, import from BR-Mid-western grid' (kilowatt hour, BR-South-eastern grid, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HN, None),
#  'electricity, high voltage, import from BG' (kilowatt hour, TR, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, NO, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-NM, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, EE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, UA, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, HR, None),
#  'electricity, high voltage, import from CA-NB' (kilowatt hour, US-NPCC, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, US-WECC, None),
#  'electricity production, lignite' (kilowatt hour, ES, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, UA, None),
#  'electricity production, lignite' (kilowatt hour, RO, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, KR, None),
#  'electricity, high voltage, import from VE' (kilowatt hour, CO, None),
#  'electricity production, solar thermal parabolic trough, 50 MW' (kilowatt hour, ZA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, GR, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, SK, None),
#  'electricity, high voltage, import from ZA' (kilowatt hour, BW, None),
#  'electricity, high voltage, import from UZ' (kilowatt hour, TJ, None),
#  'electricity, high voltage, import from AR' (kilowatt hour, BR-Southern grid, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, IN-KA, None),
#  'electricity production, deep geothermal' (kilowatt hour, NZ, None),
#  'electricity, high voltage, import from CD' (kilowatt hour, CG, None),
#  'market for electricity, high voltage' (kilowatt hour, CN-CSG, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-NM, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, SK, None),
#  'electricity production, oil' (kilowatt hour, TH, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, DK, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, EE, None),
#  'electricity, high voltage, import from AT' (kilowatt hour, IT, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, LU, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, TW, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-BJ, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, BR-North-eastern grid, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, RO, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-AS, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, FR, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IT, None),
#  'electricity, high voltage, import from MX' (kilowatt hour, US-WECC, None),
#  'electricity, high voltage, import from PY' (kilowatt hour, BR-Southern grid, None),
#  'market for electricity, high voltage' (kilowatt hour, BW, None),
#  'market group for electricity, high voltage' (kilowatt hour, CA, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-SH, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-GS, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, MK, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, LV, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CY, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, RU, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, DE, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, FI, None),
#  'electricity production, wind, 2.3MW turbine, precast concrete tower, onshore' (kilowatt hour, CA-QC, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, AT, None),
#  'electricity, high voltage, import from IN-Eastern grid' (kilowatt hour, IN-North-eastern grid, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, MY, None),
#  'market for electricity, high voltage' (kilowatt hour, MU, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, TR, None),
#  'electricity production, hard coal' (kilowatt hour, CN-SH, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, US-HICC, None),
#  'heat and power co-generation, oil' (kilowatt hour, CZ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, CA-ON, None),
#  'electricity, high voltage, import from PL' (kilowatt hour, DE, None),
#  'heat and power co-generation, oil' (kilowatt hour, US-NPCC, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-TN, None),
#  'electricity, high voltage, import from NL' (kilowatt hour, NO, None),
#  'electricity, high voltage, import from CA-MB' (kilowatt hour, CA-ON, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, JP, None),
#  'electricity production, oil' (kilowatt hour, HR, None),
#  'electricity production, hard coal' (kilowatt hour, CN-JS, None),
#  'electricity production, oil' (kilowatt hour, MT, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, ES, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-QH, None),
#  'electricity production, lignite' (kilowatt hour, GR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-HU, None),
#  'electricity production, hard coal' (kilowatt hour, IN-TN, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, LT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-JX, None),
#  'market for electricity, high voltage' (kilowatt hour, SY, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, NO, None),
#  'electricity production, oil' (kilowatt hour, LV, None),
#  'heat and power co-generation, lignite' (kilowatt hour, RoW, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-GZ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, BE, None),
#  'market for electricity, high voltage' (kilowatt hour, FI, None),
#  'market for electricity, high voltage' (kilowatt hour, ZM, None),
#  'heat and power co-generation, lignite' (kilowatt hour, RU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CA-NF, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GS, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-JS, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, US-WECC, None),
#  'electricity production, deep geothermal' (kilowatt hour, IT, None),
#  'market for electricity, high voltage' (kilowatt hour, MA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, TH, None),
#  'electricity production, oil' (kilowatt hour, FR, None),
#  'electricity, high voltage, import from SA' (kilowatt hour, AE, None),
#  'market for electricity, high voltage' (kilowatt hour, BD, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, IN-KL, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, TW, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, CL, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CY, None),
#  'heat and power co-generation, oil' (kilowatt hour, NL, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-ZJ, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, RS, None),
#  'market for electricity, high voltage' (kilowatt hour, GT, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, BR, None),
#  'market for electricity, high voltage' (kilowatt hour, PA, None),
#  'electricity, high voltage, production mix' (kilowatt hour, ER, None),
#  'electricity production, lignite' (kilowatt hour, TW, None),
#  'electricity, high voltage, production mix' (kilowatt hour, XK, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, TR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, PE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, NA, None),
#  'electricity, high voltage, import from DZ' (kilowatt hour, MA, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, ZA, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, PT, None),
#  'market for electricity, high voltage' (kilowatt hour, CA-NU, None),
#  'electricity production, deep geothermal' (kilowatt hour, NI, None),
#  'electricity production, oil' (kilowatt hour, LT, None),
#  'heat and power co-generation, oil' (kilowatt hour, GB, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CA-NB, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, SE, None),
#  'electricity, high voltage, import from CA-NS' (kilowatt hour, US-NPCC, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, US-WECC, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, ID, None),
#  'electricity production, deep geothermal' (kilowatt hour, IS, None),
#  'electricity production, oil' (kilowatt hour, CA-ON, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, RU, None),
#  'market for electricity, high voltage' (kilowatt hour, BE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-SK, None),
#  'electricity, high voltage, import from BG' (kilowatt hour, RS, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, CA-ON, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-KL, None),
#  'electricity, high voltage, import from NO' (kilowatt hour, FI, None),
#  'electricity production, oil' (kilowatt hour, TW, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, DE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-GZ, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-Southern grid, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-BR, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-AS, None),
#  'electricity production, peat' (kilowatt hour, EE, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-MN, None),
#  'electricity, high voltage, production mix' (kilowatt hour, IN-Southern grid, None),
#  'electricity production, hard coal' (kilowatt hour, IN-HR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, TR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, RS, None),
#  'electricity production, deep geothermal' (kilowatt hour, CZ, None),
#  'heat and power co-generation, natural gas, 200kW electrical, lean burn' (kilowatt hour, CH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, AU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CA-SK, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, US-WECC, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, DK, None),
#  'electricity, high voltage, import from SA' (kilowatt hour, BH, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, CA-QC, None),
#  'market for electricity, high voltage' (kilowatt hour, AU, None),
#  'electricity, high voltage, import from BR-Southern grid' (kilowatt hour, BR-South-eastern grid, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CY, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, US-MRO, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-TJ, None),
#  'electricity production, oil' (kilowatt hour, CN-SH, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, JP, None),
#  'electricity production, lignite' (kilowatt hour, TH, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-HL, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, US-SERC, None),
#  'market for electricity, high voltage' (kilowatt hour, HT, None),
#  'electricity production, hard coal' (kilowatt hour, US-MRO, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, AT, None),
#  'electricity production, deep geothermal' (kilowatt hour, FR, None),
#  'electricity production, oil' (kilowatt hour, TZ, None),
#  'electricity production, hard coal' (kilowatt hour, MY, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-HL, None),
#  'electricity production, hard coal' (kilowatt hour, CN-LN, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CA-PE, None),
#  'electricity production, oil' (kilowatt hour, CN-QH, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-XJ, None),
#  'electricity production, deep geothermal' (kilowatt hour, US-HICC, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-ZJ, None),
#  'heat and power co-generation, natural gas, 1MW electrical, lean burn' (kilowatt hour, CH, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, IT, None),
#  'electricity, high voltage, wind power, import from Germany' (kilowatt hour, CH, None),
#  'electricity, high voltage, import from IN-North-eastern grid' (kilowatt hour, IN-Northern grid, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, PE, None),
#  'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, ZA, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CA-AB, None),
#  'electricity, high voltage, production mix' (kilowatt hour, NL, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, NL, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, US-RFC, None),
#  'market group for electricity, high voltage' (kilowatt hour, CN, None),
#  'electricity, high voltage, production mix' (kilowatt hour, MY, None),
#  'electricity, high voltage, production mix' (kilowatt hour, DO, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, US-HICC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-JL, None),
#  'electricity, high voltage, import from US-NPCC' (kilowatt hour, CA-NB, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CA-AB, None),
#  'electricity, high voltage, import from GR' (kilowatt hour, TR, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, IT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, UA, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, DE, None),
#  'electricity, high voltage, import from HU' (kilowatt hour, RS, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, DK, None),
#  'electricity production, hard coal' (kilowatt hour, NL, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, GR, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, JP, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, GR, None),
#  'market for electricity, high voltage' (kilowatt hour, IR, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, RU, None),
#  'sulfate pulp production, from eucalyptus, bleached' (kilowatt hour, RLA, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, PT, None),
#  'market for electricity, high voltage' (kilowatt hour, BG, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, DE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CZ, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, CA-NS, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CW, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, CN-HU, None),
#  'electricity, high voltage, hydro, reservoir, import from France' (kilowatt hour, CH, None),
#  'heat and power co-generation, oil' (kilowatt hour, US-RFC, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, GB, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-NM, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, FI, None),
#  'electricity production, oil' (kilowatt hour, SK, None),
#  'electricity production, deep geothermal' (kilowatt hour, TR, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-JX, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, NO, None),
#  'electricity production, hard coal' (kilowatt hour, CA-PE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, AO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, NL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-South-eastern grid, None),
#  'electricity, high voltage, import from DE' (kilowatt hour, FR, None),
#  'electricity production, hard coal' (kilowatt hour, IN-AP, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, BG, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CA-AB, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, HU, None),
#  'electricity production, hard coal' (kilowatt hour, CA-NB, None),
#  'electricity, high voltage, import from US-NPCC' (kilowatt hour, CA-NS, None),
#  'electricity, high voltage, import from CA-SK' (kilowatt hour, US-MRO, None),
#  'electricity production, oil' (kilowatt hour, CO, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-SH, None),
#  'electricity, high voltage, import from DE' (kilowatt hour, PL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, RO, None),
#  'electricity production, hard coal' (kilowatt hour, AT, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CA-NF, None),
#  'heat and power co-generation, lignite' (kilowatt hour, RO, None),
#  'electricity, high voltage, import from PL' (kilowatt hour, SE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-XZ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-NPCC, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CA-AB, None),
#  'market for electricity, high voltage' (kilowatt hour, IE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CH, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, FI, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CA-SK, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CENTREL, None),
#  'electricity production, solar tower power plant, 20 MW' (kilowatt hour, RoW, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-UT, None),
#  'electricity, high voltage, import from EC' (kilowatt hour, PE, None),
#  'electricity, high voltage, import from GB' (kilowatt hour, NL, None),
#  'electricity, high voltage, import from BY' (kilowatt hour, LT, None),
#  'electricity, high voltage, import from IN-Southern grid' (kilowatt hour, IN-Western grid, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-JL, None),
#  'electricity production, hard coal' (kilowatt hour, UA, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CA-BC, None),
# ...
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, AT, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, UA, None),
#  'electricity production, oil' (kilowatt hour, DK, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-TN, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CZ, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-NX, None),
#  'electricity production, nuclear, pressure water reactor, heavy water moderated' (kilowatt hour, IN-UP, None),
#  'electricity, high voltage, import from GR' (kilowatt hour, BG, None),
#  'electricity, high voltage, import from PA' (kilowatt hour, CR, None),
#  'electricity production, hydro, reservoir, tropical region' (kilowatt hour, BR-Southern grid, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-CQ, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-JS, None),
#  'electricity production, oil' (kilowatt hour, CN-LN, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BA, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, DE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-NX, None),
#  'electricity, high voltage, production mix' (kilowatt hour, TJ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, BA, None),
#  'electricity, high voltage, import from SA' (kilowatt hour, JO, None),
#  'electricity production, hard coal' (kilowatt hour, US-TRE, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, IR, None),
#  'electricity production, oil' (kilowatt hour, EE, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, TR, None),
#  'electricity, high voltage, import from RS' (kilowatt hour, ME, None),
#  'market for electricity, high voltage' (kilowatt hour, PE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, IN-Eastern grid, None),
#  'electricity production, oil' (kilowatt hour, US-RFC, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, GR, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-LN, None),
#  'electricity production, oil' (kilowatt hour, CN-JL, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, NO, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-XJ, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-MP, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-HN, None),
#  'electricity production, nuclear, pressure water reactor, heavy water moderated' (kilowatt hour, IN-MH, None),
#  'market for electricity, high voltage' (kilowatt hour, MN, None),
#  'market for electricity, high voltage' (kilowatt hour, IL, None),
#  'electricity production, nuclear, boiling water reactor' (kilowatt hour, US-MRO, None),
#  'electricity production, oil' (kilowatt hour, BR-North-eastern grid, None),
#  'market group for electricity, high voltage' (kilowatt hour, RAF, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, US-ASCC, None),
#  'electricity production, oil' (kilowatt hour, CN-HL, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, IN-GJ, None),
#  'electricity, high voltage, import from BR-Northern grid' (kilowatt hour, BR-South-eastern grid, None),
#  'electricity production, hard coal' (kilowatt hour, CN-SA, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, KR, None),
#  'electricity production, peat' (kilowatt hour, RoW, None),
#  'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, CA-NF, None),
#  'electricity production, deep geothermal' (kilowatt hour, CL, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CH, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, SK, None),
#  'electricity production, hydro, reservoir, tropical region' (kilowatt hour, AR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, GI, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-SX, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CA-ON, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, BG, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, NE, None),
#  'electricity, high voltage, import from CA-AB' (kilowatt hour, CA-SK, None),
#  'treatment of bagasse, from sugarcane, in heat and power co-generation unit, 6400kW thermal' (kilowatt hour, BR-South-eastern grid, None),
#  'electricity production, hydro, reservoir, tropical region' (kilowatt hour, ID, None),
#  'electricity production, oil' (kilowatt hour, SI, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IT, None),
#  'electricity, high voltage, production mix' (kilowatt hour, AE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-AR, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, ES, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, IR, None),
#  'electricity production, hard coal' (kilowatt hour, IN-GJ, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, US-SERC, None),
#  'heat and power co-generation, wood chips, 6667 kW' (kilowatt hour, LV, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CA-BC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, LU, None),
#  'electricity, high voltage, import from DE' (kilowatt hour, LU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, SG, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-TJ, None),
#  'electricity production, oil' (kilowatt hour, IE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, GE, None),
#  'electricity production, oil' (kilowatt hour, PE, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CI, None),
#  'electricity, high voltage, production mix' (kilowatt hour, UZ, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-UP, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IN-HR, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CA-MB, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-TJ, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-BJ, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-QH, None),
#  'electricity, high voltage, import from HU' (kilowatt hour, RO, None),
#  'electricity production, wind, 1-3MW turbine, offshore' (kilowatt hour, GB, None),
#  'market for electricity, high voltage' (kilowatt hour, JM, None),
#  'electricity production, hard coal' (kilowatt hour, TW, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, IT, None),
#  'electricity production, deep geothermal' (kilowatt hour, LT, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, US-SERC, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, CN-GD, None),
#  'electricity, high voltage, import from IT' (kilowatt hour, MT, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, CN-JX, None),
#  'heat and power co-generation, oil' (kilowatt hour, DE, None),
#  'electricity production, hard coal' (kilowatt hour, CN-ZJ, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, HU, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, SE, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, ES, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-QH, None),
#  'electricity production, hard coal' (kilowatt hour, IT, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, AR, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, CN-SH, None),
#  'market for electricity, high voltage' (kilowatt hour, HU, None),
#  'electricity, high voltage, import from ZA' (kilowatt hour, MZ, None),
#  'electricity, high voltage, production mix' (kilowatt hour, AM, None),
#  'electricity production, lignite' (kilowatt hour, US-TRE, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, SK, None),
#  'market group for electricity, high voltage' (kilowatt hour, RNA, None),
#  'electricity production, oil' (kilowatt hour, US-NPCC, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, LT, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, BG, None),
#  'market for electricity, high voltage' (kilowatt hour, DE, None),
#  'electricity, high voltage, import from AZ' (kilowatt hour, RU, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IN-SK, None),
#  'heat and power co-generation, oil' (kilowatt hour, LU, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-RFC, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-GZ, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-HU, None),
#  'electricity production, hydro, reservoir, tropical region' (kilowatt hour, BR-South-eastern grid, None),
#  'heat and power co-generation, oil' (kilowatt hour, US-HICC, None),
#  'electricity, high voltage, production mix' (kilowatt hour, TH, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, IN-RJ, None),
#  'electricity, high voltage, import from IN-Eastern grid' (kilowatt hour, IN-Northern grid, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-SX, None),
#  'heat and power co-generation, natural gas, conventional power plant, 100MW electrical' (kilowatt hour, US-TRE, None),
#  'electricity, high voltage, import from GH' (kilowatt hour, CI, None),
#  'electricity production, hydro, reservoir, alpine region' (kilowatt hour, RS, None),
#  'market for electricity, high voltage' (kilowatt hour, GA, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-RFC, None),
#  'market for electricity, high voltage' (kilowatt hour, TJ, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, BR-Mid-western grid, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, HR, None),
#  'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, IN-TN, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, KR, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, GR, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CA-NB, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, CA-ON, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, TW, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, SI, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-PR, None),
#  'heat and power co-generation, oil' (kilowatt hour, PT, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-GD, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, PL, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, BG, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, IN-TN, None),
#  'electricity, high voltage, production mix' (kilowatt hour, US-NPCC, None),
#  'market for electricity, high voltage' (kilowatt hour, IS, None),
#  'electricity production, hydro, run-of-river' (kilowatt hour, IR, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, IN-BR, None),
#  'electricity, high voltage, import from RS' (kilowatt hour, XK, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, JP, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, US-ASCC, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, RO, None),
#  'electricity, high voltage, import from MA' (kilowatt hour, ES, None),
#  'electricity, high voltage, production mix' (kilowatt hour, FI, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-JX, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-GS, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CO, None),
#  'heat and power co-generation, oil' (kilowatt hour, IT, None),
#  'market for electricity, high voltage' (kilowatt hour, OM, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, IN-AP, None),
#  'treatment of coal gas, in power plant' (kilowatt hour, KR, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, BE, None),
#  'market for electricity, high voltage' (kilowatt hour, US-HICC, None),
#  'electricity production, hydro, pumped storage' (kilowatt hour, IN-WB, None),
#  'electricity production, oil' (kilowatt hour, JP, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, PT, None),
#  'electricity production, nuclear, pressure water reactor, heavy water moderated' (kilowatt hour, RU, None),
#  'treatment of digester sludge, municipal incineration, future' (kilowatt hour, CH, None),
#  'electricity, high voltage, nuclear, import from France' (kilowatt hour, CH, None),
#  'electricity, high voltage, import from IR' (kilowatt hour, TR, None),
#  'electricity production, deep geothermal' (kilowatt hour, US-WECC, None),
#  'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, KR, None),
#  'heat and power co-generation, hard coal' (kilowatt hour, DE, None),
#  'market for electricity, high voltage' (kilowatt hour, CN-SGCC, None),
#  'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (kilowatt hour, SA, None),
#  'sulfate pulp production, from eucalyptus, bleached' (kilowatt hour, RoW, None),
#  'electricity, high voltage, import from RS' (kilowatt hour, BA, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CA-NT, None),
#  'electricity, high voltage, import from BA' (kilowatt hour, ME, None),
#  'electricity, high voltage, production mix' (kilowatt hour, CN-XJ, None),
#  'electricity, high voltage, import from CR' (kilowatt hour, NI, None),
#  'electricity, high voltage, import from DE' (kilowatt hour, SE, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, US-MRO, None),
#  'electricity production, oil' (kilowatt hour, CN-GX, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, IR, None),
#  'electricity, high voltage, production mix' (kilowatt hour, PT, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CN-HE, None),
#  'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-GD, None),
#  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-JL, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, RO, None),
#  'electricity production, natural gas, conventional power plant' (kilowatt hour, NO, None),
#  'electricity production, hard coal' (kilowatt hour, TR, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, US-NPCC, None),
#  'electricity production, lignite' (kilowatt hour, SI, None),
#  ...]

# %% [markdown]
# Let's retrieve the activity of our functional unit and specify the demand as a dictionary:

# %%
electricity_market = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
electricity_market
# Out:
# ['market for electricity, high voltage' (kilowatt hour, DE, None)]

# %% [markdown]
# Setting a demand of 128,819.0 GWh of electricity according to [Germany electricity demand 2018](https://www.destatis.de/EN/Themes/Society-Environment/Environment/Material-Energy-Flows/Tables/electricity-consumption-households.html)

# %%
demand = {electricity_market[0]: 1.28819e+11}

# %% [markdown]
# ### Specify the **choices**

# %% [markdown]
# The choices are specified similar to the demand / functional unit. First, search for the processes with equivalent products:

# %%
activities = ["electricity production, lignite", 
             "electricity production, hard coal",
             "electricity production, nuclear, pressure water reactor",
             "electricity production, wind, 1-3MW turbine, onshore"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

electricity_activities = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
electricity_activities
# Out:
# ['electricity production, lignite' (kilowatt hour, DE, None),
#  'electricity production, hard coal' (kilowatt hour, DE, None),
#  'electricity production, nuclear, pressure water reactor' (kilowatt hour, DE, None),
#  'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, DE, None)]

# %% [markdown]
# These are the currently four most employed technologies for electricity production in Germany (lignite: 24.2%, wind: 15.4%, coal: 11.9%, nuclear: 10.6%) according to the "_market for electricity, high voltage (DE)_"

# %% [markdown]
# Specify also the choices as a dictionary. Be aware, that this time we are dealing with a dictionary of dictionaries. Each inner dictionary corresponds to one type of choice in the background! Here, we only consider choices between electricity production activities, so we assign the key "electricity" to the equivalent product they produce.
#
# The assigned value in the inner dictionary is the capacity limit of this activity, which for now is set to a very high value, to consider an unconstrained situation.

# %%
choices  = {'electricity': {electricity_activities[0]: 1e16,
                         electricity_activities[1]: 1e16,
                         electricity_activities[2]: 1e16,
                         electricity_activities[3]: 1e16}}

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">(3) Solution</h2>
# </div>

# %% [markdown]
# ### Instantiate the worker

# %%
instance = pulpo_worker.instantiate(choices=choices, demand=demand)
# Out:
# Creating Instance
# Instance created

# %% [markdown]
# ### Solve the instance

# %% [markdown]
# When specifying a valid GAMS_PATH with a licence for CPLEX, as shown below, CPLEX with fine-tuned parameters is automatically selected to solve the Linear Problem (**LP**).
#
# If no GAMS_PATH is specified, the "[HiGHS](https://highs.dev/)" solver is automatically used. It has almost double the run time of "CPLEX".

# %%
#results = pulpo_worker.solve()
# Alternatively using GAMS (cplex) solvers:
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         9.57 seconds required for presolve
# --- Job model.gms Start 12/10/23 10:56:30 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143663) 38 Mb
# --- model.gms(144269) 43 Mb
# --- model.gms(269559) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\cplex.opt
# --- model.gms(269567) 65 Mb
# --- model.gms(323110) 71 Mb
# --- model.gms(393517) 89 Mb
# --- Starting execution: elapsed 0:00:00.589
# --- model.gms(269558) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(143560) 107 Mb
# --- model.gms(144251) 112 Mb
# --- model.gms(269566) 127 Mb
# --- model.gms(269566) 127 Mb
# ---   82,598 rows  41,300 columns  676,406 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.057
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.93 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.02 Mb (peak 45.34 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.27 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 111190 rows and 28593 columns.
# Aggregator did 9385 substitutions.
# Reduced LP has 3319 rows, 3322 columns, and 100046 nonzeros.
# Presolve time = 0.38 sec. (918.82 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.474670
# Iteration:    86   Scaled dual infeas =            47.405841
# Iteration:   163   Scaled dual infeas =            44.368386
# Iteration:   243   Scaled dual infeas =            40.883856
# Iteration:   316   Scaled dual infeas =            39.912683
# Iteration:   390   Scaled dual infeas =            39.193033
# Iteration:   471   Scaled dual infeas =            38.614790
# Iteration:   547   Scaled dual infeas =            38.543896
# Iteration:   626   Scaled dual infeas =            37.397613
# Iteration:   711   Scaled dual infeas =            31.520890
# Iteration:   790   Scaled dual infeas =            30.815913
# Iteration:   862   Scaled dual infeas =            28.959280
# Iteration:   942   Scaled dual infeas =            28.006524
# Iteration:  1023   Scaled dual infeas =            27.464379
# Iteration:  1102   Scaled dual infeas =            27.135122
# Iteration:  1180   Scaled dual infeas =            26.015790
# Iteration:  1259   Scaled dual infeas =            25.270040
# Iteration:  1344   Scaled dual infeas =            17.232044
# Iteration:  1428   Scaled dual infeas =            13.336856
# Iteration:  1517   Scaled dual infeas =            11.370320
# Iteration:  1603   Scaled dual infeas =            10.109186
# Iteration:  1691   Scaled dual infeas =             9.575695
# Iteration:  1784   Scaled dual infeas =             8.305191
# Iteration:  1874   Scaled dual infeas =             7.211378
# Iteration:  1970   Scaled dual infeas =             5.049294
# Iteration:  2065   Scaled dual infeas =             3.392900
# Iteration:  2162   Scaled dual infeas =             2.694988
# Iteration:  2261   Scaled dual infeas =             2.413233
# Iteration:  2359   Scaled dual infeas =             2.049437
# Iteration:  2460   Scaled dual infeas =             1.223871
# Iteration:  2562   Scaled dual infeas =             0.905910
# Markowitz threshold set to 0.1
# Iteration:  2667   Scaled dual infeas =             0.353218
# Iteration:  2722   Dual objective     =   16212404748.558594
# Removing shift (43).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.55sec (det. 9233.84 ticks)
#
#
# Optimal solution found
# Objective:  16247142100.996704
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.698
# --- model.gms(269569) 127 Mb
# --- model.gms(393517) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393517) 124 Mb
# --- Job model.gms Stop 12/10/23 10:56:34 elapsed 0:00:03.881
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmpmvyp07f9
#
#         4.62 seconds required for solver
#         0.32 seconds required for postsolve
#        14.51 seconds required total

# %% [markdown]
# ### Save and summarize the results 💾📈

# %% [markdown]
# The "**save_results()**" function will save the results in an processed format to an excel file in the data folder that has been specified at the beginning.

# %%
pulpo_worker.save_results(choices=choices, demand=demand, name='electricity_showcase_results.xlsx')

# %% [markdown]
# You can inspect the generated excel file.

# %% [markdown]
# There is another function to summarize the results in dataframe form within jupyter notbeooks called "summarize_results". This function has similar inputs to the "save_results" function, but does not require the specification of a filename. Additionally, by specifying the "*zeroes*" parameter to "*True*" all the not-selected choices are omitted in the summary.

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, zeroes=True)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  1.624714e+10
# The following choices were made:
# electricity
#                                                                                          electricity  \
#                                                                                             Activity
# Activity 0  electricity production, nuclear, pressure water reactor | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  8.360521e+10
# No additional constraints have been passed.

# %% [markdown]
# # Closing Remarks

# %% [markdown]
# This is the end of the very basic PULPO functionalities using the electricity case study.

# %% [markdown]
# The following sections will dive deeper into additional functionalities.

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Additional Constraints</h2>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="pictures/electricity_showcase_2.png" alt="Image Alt Text" style="width: 50%;" />
# </div>

# %% [markdown]
# #### Technosphere Flows

# %% [markdown]
# Let's assess what happens if the "_electricity production, nuclear, pressure water reactor | electricity, high voltage | DE_" activity is indirectly constrained trough a restriction on "_nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX_"

# %%
activities = ["market for nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX"]
reference_products = ["nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX"]
locations = ["GLO"]

nuclear_fuel = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
nuclear_fuel
# Out:
# ['market for nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX' (kilogram, GLO, None)]

# %%
upper_limit = {nuclear_fuel[0]: 100000}

# %% [markdown]
# The rationale behind choosing this activity and this limit is based on inspection of the scaling vector of the previous results. This activity is limiting for the nuclear electricity activity but not for the others, so, to enforce a different result than before, this activity is constrained.

# %%
pulpo_worker.instantiate(choices=choices, demand=demand, upper_limit=upper_limit)
results = pulpo_worker.solve()
# Out:
# Creating Instance
# Instance created

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, constraints=upper_limit)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  1.664559e+10
# The following choices were made:
# electricity
#                                                                                          electricity  \
#                                                                                             Activity
# Activity 0                          electricity production, lignite | electricity, high voltage | DE
# Activity 1                        electricity production, hard coal | electricity, high voltage | DE
# Activity 2  electricity production, nuclear, pressure water reactor | electricity, high voltage | DE
# Activity 3     electricity production, wind, 1-3MW turbine, onshore | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16 -0.000000e+00
# Activity 1  1.000000e+16 -0.000000e+00
# Activity 2  1.000000e+16  3.952569e+10
# Activity 3  1.000000e+16  4.397562e+10
# The following constraints were implemented and oblieged:
#                                                                                                                                                       Constraints
# market for nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX | nuclear fuel element, for pressure water reactor, UO2 4.0% & MOX | GLO       100000

# %% [markdown]
# As can be seen from the summary above, part of the final electricity demand is supplied by the wind turbine processes, because the nuclear process is constrained by the nuclear fuel process. It is also evident that the impact is higher than the previous one, as the GWP minimizing process (nuclear) can no longer supply the full demand.

# %% [markdown]
# #### Elementary Flows

# %% [markdown]
# Apart from technosphere flows, elementary flows may also be constrained. This could be a limitation on the extraction of raw materials or the emission of a certain compound. In this case study, we limit the emission of Radon-22:

# %%
elem = pulpo_worker.retrieve_envflows(activities='Radon-222')
elem
# Out:
# ['Radon-222' (kilo Becquerel, None, ('air',)),
#  'Radon-222' (kilo Becquerel, None, ('air', 'urban air close to ground')),
#  'Radon-222' (kilo Becquerel, None, ('air', 'low population density, long-term')),
#  'Radon-222' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')),
#  'Radon-222' (kilo Becquerel, None, ('air', 'lower stratosphere + upper troposphere'))]

# %% [markdown]
# As can be seen from the results of the previous assessment, the "low population density, long-term" emission is the largest elementary flow with 3.69x1E13 kg Becquerel. For testing purpose, we limit this emissio to 1.00x1E13 kg Becquerel:

# %%
elem = [flow for flow in elem if 'long-term' in str(flow)]
elem_limit = {elem[0]: 1e13}
instance = pulpo_worker.instantiate(choices=choices, demand=demand, upper_elem_limit=elem_limit)
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         8.98 seconds required for presolve
# --- Job model.gms Start 12/10/23 10:57:57 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143551) 37 Mb
# --- model.gms(144331) 44 Mb
# --- model.gms(269559) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\cplex.opt
# --- model.gms(269567) 65 Mb
# --- model.gms(309235) 69 Mb
# --- model.gms(393517) 89 Mb
# --- Starting execution: elapsed 0:00:00.593
# --- model.gms(269558) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(143630) 108 Mb
# --- model.gms(144387) 114 Mb
# --- model.gms(269566) 127 Mb
# ---   82,598 rows  41,300 columns  676,406 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.047
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.93 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.02 Mb (peak 45.34 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.27 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# LP Presolve eliminated 111146 rows and 28551 columns.
# Aggregator did 9423 substitutions.
# Reduced LP has 3324 rows, 3326 columns, and 100060 nonzeros.
# Presolve time = 0.41 sec. (995.01 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.176572
# Iteration:    93   Scaled dual infeas =            47.088037
# Iteration:   186   Scaled dual infeas =            41.154520
# Iteration:   266   Scaled dual infeas =            40.044498
# Iteration:   338   Scaled dual infeas =            39.057822
# Iteration:   419   Scaled dual infeas =            38.576997
# Iteration:   497   Scaled dual infeas =            38.420082
# Iteration:   572   Scaled dual infeas =            37.098900
# Iteration:   652   Scaled dual infeas =            35.938745
# Iteration:   734   Scaled dual infeas =            30.558024
# Iteration:   815   Scaled dual infeas =            29.440102
# Iteration:   890   Scaled dual infeas =            28.284532
# Iteration:   971   Scaled dual infeas =            27.281867
# Iteration:  1053   Scaled dual infeas =            26.629232
# Iteration:  1131   Scaled dual infeas =            26.188929
# Iteration:  1213   Scaled dual infeas =            25.277981
# Iteration:  1299   Scaled dual infeas =            22.638586
# Markowitz threshold set to 0.1
# Iteration:  1381   Scaled dual infeas =            17.011717
# Iteration:  1470   Scaled dual infeas =            11.692000
# Iteration:  1554   Scaled dual infeas =            11.273852
# Iteration:  1642   Scaled dual infeas =             9.242565
# Iteration:  1731   Scaled dual infeas =             8.229399
# Iteration:  1823   Scaled dual infeas =             7.373181
# Iteration:  1917   Scaled dual infeas =             6.291935
# Iteration:  2013   Scaled dual infeas =             3.928983
# Iteration:  2104   Scaled dual infeas =             3.243039
# Iteration:  2200   Scaled dual infeas =             2.440152
# Iteration:  2302   Scaled dual infeas =             1.897446
# Iteration:  2403   Scaled dual infeas =             1.670584
# Iteration:  2504   Scaled dual infeas =             1.114219
# Iteration:  2612   Scaled dual infeas =             0.693988
# Iteration:  2722   Dual objective     =   16212398901.590820
# Removing shift (39).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.50sec (det. 8956.50 ticks)
#
#
# Optimal solution found
# Objective:  17162924572.819267
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.640
# --- model.gms(269569) 127 Mb
# --- model.gms(393517) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393517) 124 Mb
# --- Job model.gms Stop 12/10/23 10:58:01 elapsed 0:00:03.828
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmpv8yghurp
#
#         5.41 seconds required for solver
#         0.34 seconds required for postsolve
#        14.73 seconds required total

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  1.716292e+10
# The following choices were made:
# electricity
#                                                                                          electricity  \
#                                                                                             Activity
# Activity 0                          electricity production, lignite | electricity, high voltage | DE
# Activity 1                        electricity production, hard coal | electricity, high voltage | DE
# Activity 2  electricity production, nuclear, pressure water reactor | electricity, high voltage | DE
# Activity 3     electricity production, wind, 1-3MW turbine, onshore | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  0.000000e+00
# Activity 1  1.000000e+16  0.000000e+00
# Activity 2  1.000000e+16  1.674902e+10
# Activity 3  1.000000e+16  6.677409e+10
# No additional constraints have been passed.

# %% [markdown]
# As can be seen, the share of nuclear power is limited through the introduced elementary flow constraint.

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Additional Methods</h2>
# </div>

# %% [markdown]
# Let's see how to evaluate different methods and set them as objectives, in this case evaluating the ReCiPe endpoints, and setting the human health one as objective:

# %%
methods = {"('IPCC 2013', 'climate change', 'GWP 100a')": 0,
           "('ReCiPe Endpoint (E,A)', 'resources', 'total')": 0,
           "('ReCiPe Endpoint (E,A)', 'human health', 'total')": 1,
           "('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')": 0}

# %% [markdown]
# With this, a new Pulpo worker must be created:

# %%
pulpo_worker = pulpo.PulpoOptimizer(project, database, methods, directory)

# %%
pulpo_worker.get_lci_data()

# %%
pulpo_worker.instantiate(choices=choices, demand=demand)
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         8.91 seconds required for presolve
# --- Job model.gms Start 12/10/23 10:58:28 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143579) 37 Mb
# --- model.gms(144224) 43 Mb
# --- model.gms(269559) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\cplex.opt
# --- model.gms(269567) 65 Mb
# --- model.gms(316050) 70 Mb
# --- model.gms(393517) 89 Mb
# --- Starting execution: elapsed 0:00:00.578
# --- model.gms(269558) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(143801) 109 Mb
# --- model.gms(144513) 115 Mb
# --- model.gms(269566) 127 Mb
# ---   82,598 rows  41,300 columns  677,099 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.032
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.93 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.02 Mb (peak 45.34 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.27 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 111190 rows and 28593 columns.
# Aggregator did 9385 substitutions.
# Reduced LP has 3319 rows, 3322 columns, and 100046 nonzeros.
# Presolve time = 0.36 sec. (920.82 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =             8.094161
# Iteration:    87   Scaled dual infeas =             7.968469
# Iteration:   162   Scaled dual infeas =             7.890913
# Iteration:   238   Scaled dual infeas =             7.670857
# Iteration:   314   Scaled dual infeas =             7.637684
# Iteration:   386   Scaled dual infeas =             7.620673
# Iteration:   459   Scaled dual infeas =             7.472495
# Iteration:   533   Scaled dual infeas =             7.314159
# Iteration:   610   Scaled dual infeas =             7.146669
# Iteration:   690   Scaled dual infeas =             6.153532
# Iteration:   770   Scaled dual infeas =             5.896408
# Iteration:   852   Scaled dual infeas =             5.875879
# Iteration:   934   Scaled dual infeas =             5.834047
# Iteration:  1014   Scaled dual infeas =             5.801228
# Iteration:  1093   Scaled dual infeas =             5.761939
# Iteration:  1171   Scaled dual infeas =             5.489621
# Iteration:  1257   Scaled dual infeas =             4.943697
# Iteration:  1341   Scaled dual infeas =             4.309927
# Iteration:  1425   Scaled dual infeas =             2.584639
# Iteration:  1508   Scaled dual infeas =             2.439848
# Iteration:  1596   Scaled dual infeas =             2.164979
# Iteration:  1681   Scaled dual infeas =             2.094630
# Iteration:  1766   Scaled dual infeas =             2.032818
# Iteration:  1861   Scaled dual infeas =             1.815959
# Iteration:  1949   Scaled dual infeas =             1.630523
# Iteration:  2045   Scaled dual infeas =             1.511972
# Iteration:  2138   Scaled dual infeas =             1.360945
# Iteration:  2237   Scaled dual infeas =             1.255599
# Iteration:  2332   Scaled dual infeas =             1.216215
# Iteration:  2430   Scaled dual infeas =             0.934194
# Iteration:  2530   Scaled dual infeas =             0.577691
# Markowitz threshold set to 0.1
# Iteration:  2633   Scaled dual infeas =             0.401889
# Iteration:  2741   Scaled dual infeas =             0.169152
# Iteration:  2803   Dual objective     =    2179311876.084473
# Removing shift (84).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.47sec (det. 9183.85 ticks)
#
#
# Optimal solution found
# Objective:   2183741148.580845
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.610
# --- model.gms(269569) 127 Mb
# --- model.gms(393517) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393517) 124 Mb
# --- Job model.gms Stop 12/10/23 10:58:31 elapsed 0:00:03.781
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmpuanwir_k
#
#         7.22 seconds required for solver
#         0.34 seconds required for postsolve
#        16.47 seconds required total

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, zeroes=True)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                                   Key         Value
# 0  ('ReCiPe Endpoint (E,A)', 'human health', 'total')  2.183741e+09
# The following impacts were calculated:
#                                                        Key         Value
# 0              ('IPCC 2013', 'climate change', 'GWP 100a')  1.739235e+10
# 1       ('ReCiPe Endpoint (E,A)', 'human health', 'total')  2.183741e+09
# 3          ('ReCiPe Endpoint (E,A)', 'resources', 'total')  9.161819e+08
# 2  ('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')  7.363601e+08
# The following choices were made:
# electricity
#                                                                                       electricity  \
#                                                                                          Activity
# Activity 0  electricity production, wind, 1-3MW turbine, onshore | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  8.350255e+10
# No additional constraints have been passed.

# %% [markdown]
# From the summary above, it can be seen that for the "_human health_" category, the nuclear process is not the most suitable anymore. With this objective, the wind turbine process is selected.
#
# As another category is minimized, the GWP has changed as well: previously, with nuclear electricity the total GWP was 1.599836e+10 while with wind electricity it is 1.739234e+10.

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Lower Level Decisions</h2>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="pictures/electricity_showcase_3.png" alt="Image Alt Text" style="width: 50%;" />
# </div>

# %% [markdown]
# In this case study, we would like to keep the current share of the electricity supplied by fossil sources the same. The choices that we consider on the electricity production level are between the coal and lignite activities:

# %%
methods = {"('IPCC 2013', 'climate change', 'GWP 100a')": 1,
           "('ReCiPe Endpoint (E,A)', 'resources', 'total')": 0,
           "('ReCiPe Endpoint (E,A)', 'human health', 'total')": 0,
           "('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')": 0}

# %%
pulpo_worker = pulpo.PulpoOptimizer(project, database, methods, directory)
pulpo_worker.get_lci_data()

# %%
activities = ["electricity production, lignite", 
             "electricity production, hard coal"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

electricity_activities = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %% [markdown]
# Instead of assessing only the **technology** choices, we are invetigating the best **regional** choice for the source of coal and lignite:

# %%
coal_activities = ["market for hard coal"]
lignite_activities = ["market for lignite"]

coal_activities = pulpo_worker.retrieve_activities(activities=coal_activities)
lignite_activities = pulpo_worker.retrieve_activities(activities=lignite_activities)

# %% [markdown]
# The updated choice dictionary looks like this:

# %%
choices  = {'electricity': {elec: 1e16 for elec in electricity_activities},
            'coal': {coal: 1e16 for coal in coal_activities},
            'lignite': {lignite: 1e16 for lignite in lignite_activities}}

# %% [markdown]
# Instantiating and solving the adapted problem:

# %%
pulpo_worker.instantiate(choices=choices, demand=demand)
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         9.14 seconds required for presolve
# --- Job model.gms Start 12/10/23 10:59:06 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143543) 38 Mb
# --- model.gms(144164) 43 Mb
# --- model.gms(264863) 63 Mb
# --- model.gms(269505) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\cplex.opt
# --- model.gms(299247) 68 Mb
# --- model.gms(393436) 89 Mb
# --- Starting execution: elapsed 0:00:00.593
# --- model.gms(269504) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(143492) 107 Mb
# --- model.gms(144300) 113 Mb
# --- model.gms(269512) 127 Mb
# --- model.gms(269512) 127 Mb
# ---   82,580 rows  41,291 columns  675,682 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.062
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.92 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.02 Mb (peak 45.33 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.26 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# LP Presolve eliminated 111170 rows and 28584 columns.
# Aggregator did 9386 substitutions.
# Reduced LP has 3309 rows, 3321 columns, and 99509 nonzeros.
# Presolve time = 0.39 sec. (992.94 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.085476
# Iteration:    91   Scaled dual infeas =            47.050371
# Iteration:   167   Scaled dual infeas =            43.705041
# Iteration:   256   Scaled dual infeas =            39.915535
# Iteration:   331   Scaled dual infeas =            38.817456
# Iteration:   412   Scaled dual infeas =            37.999528
# Iteration:   488   Scaled dual infeas =            37.534733
# Iteration:   571   Scaled dual infeas =            36.336716
# Iteration:   658   Scaled dual infeas =            29.614296
# Iteration:   743   Scaled dual infeas =            25.607969
# Iteration:   827   Scaled dual infeas =            25.037159
# Iteration:   912   Scaled dual infeas =            23.816447
# Iteration:   994   Scaled dual infeas =            23.343278
# Iteration:  1073   Scaled dual infeas =            22.185226
# Iteration:  1152   Scaled dual infeas =            21.705371
# Iteration:  1236   Scaled dual infeas =            17.189337
# Iteration:  1313   Scaled dual infeas =            16.404780
# Iteration:  1396   Scaled dual infeas =            12.516487
# Iteration:  1479   Scaled dual infeas =            10.715745
# Iteration:  1568   Scaled dual infeas =             9.623788
# Iteration:  1658   Scaled dual infeas =             8.810607
# Iteration:  1748   Scaled dual infeas =             8.270389
# Iteration:  1842   Scaled dual infeas =             6.726850
# Iteration:  1936   Scaled dual infeas =             5.128923
# Iteration:  2030   Scaled dual infeas =             3.359171
# Iteration:  2128   Scaled dual infeas =             2.245428
# Iteration:  2225   Scaled dual infeas =             2.074324
# Iteration:  2320   Scaled dual infeas =             1.880559
# Iteration:  2420   Scaled dual infeas =             1.144229
# Iteration:  2522   Scaled dual infeas =             0.973806
# Iteration:  2627   Scaled dual infeas =             0.343627
# Markowitz threshold set to 0.1
# Iteration:  2713   Dual objective     =  -21311289835.414722
# Removing shift (52).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.49sec (det. 8747.05 ticks)
#
#
# Optimal solution found
# Objective:  61602251155.341728
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.656
# --- model.gms(269515) 127 Mb
# --- model.gms(393436) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393436) 124 Mb
# --- Job model.gms Stop 12/10/23 10:59:10 elapsed 0:00:03.843
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmphbzwi0xr
#
#         4.97 seconds required for solver
#         0.33 seconds required for postsolve
#        14.44 seconds required total

# %% [markdown]
# Visualizing the results

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, zeroes=True)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  6.160225e+10
# The following impacts were calculated:
#                                                        Key         Value
# 0              ('IPCC 2013', 'climate change', 'GWP 100a')  6.160225e+10
# 1       ('ReCiPe Endpoint (E,A)', 'human health', 'total')  7.937092e+09
# 3          ('ReCiPe Endpoint (E,A)', 'resources', 'total')  2.177157e+09
# 2  ('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')  2.101987e+09
# The following choices were made:
# electricity
#                                                                    electricity  \
#                                                                       Activity
# Activity 0  electricity production, hard coal | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  4.857788e+10
# coal
#                                              coal
#                                          Activity      Capacity         Value
# Activity 0  market for hard coal | hard coal | ZA  1.000000e+16  2.189073e+10
# lignite
#                                        lignite
#                                       Activity      Capacity         Value
# Activity 0  market for lignite | lignite | RER  1.000000e+16  1.884971e+09
# No additional constraints have been passed.

# %% [markdown]
# I can be seen that out of the fossil alternatives, the electricity from coal minimizes GWP when the coal comes from RLA [Latin America and the Caribbean] (omitting transport emissions). Moreover, it can be seen that the market for lignite is somewhere used upstream of the coal production activity. In the place where it is used, the RER market for lignite is the preferred one. The lignite consumption is one order of magnitude lower than the coal consumption.

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Supply vs. Demand Problem</h2>
# </div>

# %% [markdown]
# Finally, let's test and assess the functionality of PULPO to specify supply values rather than demand values. This can be done by setting the lower_limit and the upper_limit of activities to the same value. This will enforce the corresponding scaling vector entry of that activity to the specified value, and activates the slack variable to relax the demand value.

# %% [markdown]
# This can simply be done by specifying the upper and lower limits rather than the demand (note, we continue with the choices from the previous section):

# %%
upper_limit = {electricity_market[0]: 1.28819e+11}
lower_limit = {electricity_market[0]: 1.28819e+11}

# %%
pulpo_worker.instantiate(choices=choices, upper_limit=upper_limit, lower_limit=lower_limit)
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         8.92 seconds required for presolve
# --- Job model.gms Start 12/10/23 10:59:35 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143523) 37 Mb
# --- model.gms(144164) 43 Mb
# --- model.gms(269494) 65 Mb
# --- model.gms(269505) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\cplex.opt
# --- model.gms(313869) 69 Mb
# --- model.gms(393436) 89 Mb
# --- Starting execution: elapsed 0:00:00.594
# --- model.gms(269504) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(143703) 108 Mb
# --- model.gms(144300) 113 Mb
# --- model.gms(269512) 127 Mb
# ---   82,580 rows  41,291 columns  675,682 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.032
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.92 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.02 Mb (peak 45.33 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.26 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 111191 rows and 28607 columns.
# Aggregator did 9367 substitutions.
# Reduced LP has 3306 rows, 3317 columns, and 99403 nonzeros.
# Presolve time = 0.36 sec. (915.83 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            49.870149
# Iteration:    89   Scaled dual infeas =            46.872431
# Iteration:   169   Scaled dual infeas =            40.841945
# Iteration:   249   Scaled dual infeas =            39.802885
# Iteration:   326   Scaled dual infeas =            38.803407
# Iteration:   402   Scaled dual infeas =            38.229222
# Iteration:   474   Scaled dual infeas =            37.631574
# Iteration:   560   Scaled dual infeas =            37.278523
# Iteration:   642   Scaled dual infeas =            31.637841
# Iteration:   735   Scaled dual infeas =            29.338120
# Iteration:   821   Scaled dual infeas =            25.370213
# Iteration:   901   Scaled dual infeas =            24.819462
# Iteration:   982   Scaled dual infeas =            23.722495
# Iteration:  1063   Scaled dual infeas =            23.435439
# Iteration:  1142   Scaled dual infeas =            21.852163
# Iteration:  1217   Scaled dual infeas =            21.256122
# Iteration:  1302   Scaled dual infeas =            18.250483
# Iteration:  1384   Scaled dual infeas =            13.284523
# Iteration:  1467   Scaled dual infeas =            11.019701
# Iteration:  1551   Scaled dual infeas =            10.136112
# Iteration:  1638   Scaled dual infeas =             8.891315
# Iteration:  1734   Scaled dual infeas =             8.189873
# Iteration:  1824   Scaled dual infeas =             6.761160
# Iteration:  1920   Scaled dual infeas =             4.447379
# Iteration:  2008   Scaled dual infeas =             3.452896
# Iteration:  2105   Scaled dual infeas =             2.737596
# Iteration:  2200   Scaled dual infeas =             2.267358
# Iteration:  2299   Scaled dual infeas =             1.957020
# Iteration:  2399   Scaled dual infeas =             1.207220
# Iteration:  2499   Scaled dual infeas =             1.047467
# Iteration:  2601   Scaled dual infeas =             0.448154
# Markowitz threshold set to 0.1
# Iteration:  2704   Dual objective     = -110116958063.916626
# Removing shift (34).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.31sec (det. 8604.22 ticks)
#
#
# Optimal solution found
# Objective:  58907428624.950829
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.454
# --- model.gms(269515) 127 Mb
# --- model.gms(393436) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393436) 124 Mb
# --- Job model.gms Stop 12/10/23 10:59:39 elapsed 0:00:03.625
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmp8x7vdfur
#
#         5.39 seconds required for solver
#         0.35 seconds required for postsolve
#        14.66 seconds required total

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, constraints=upper_limit, zeroes=True)
# Out:
# The following demand / functional unit has been specified:
#                                                                              Demand
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  5.890743e+10
# The following impacts were calculated:
#                                                        Key         Value
# 0              ('IPCC 2013', 'climate change', 'GWP 100a')  5.890743e+10
# 1       ('ReCiPe Endpoint (E,A)', 'human health', 'total')  7.589880e+09
# 3          ('ReCiPe Endpoint (E,A)', 'resources', 'total')  2.081916e+09
# 2  ('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')  2.010035e+09
# The following choices were made:
# electricity
#                                                                    electricity  \
#                                                                       Activity
# Activity 0  electricity production, hard coal | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  4.645281e+10
# coal
#                                              coal
#                                          Activity      Capacity         Value
# Activity 0  market for hard coal | hard coal | ZA  1.000000e+16  2.093311e+10
# lignite
#                                        lignite
#                                       Activity      Capacity         Value
# Activity 0  market for lignite | lignite | RER  1.000000e+16  1.802512e+09
# The following constraints were implemented and oblieged:
#                                                                         Constraints
# market for electricity, high voltage | electricity, high voltage | DE  1.288190e+11

# %% [markdown]
# From the results it can be observed that the resulting GWP is **considerably** lower (6.191744e+10 vs. 5.920967e+10: ~4.4%) than in the previous section. Now, the production value (supply) of electricity is specified, so that electricity consumed in the background is accounted for in the specifications.
#
# Overall, when specifying supply values instead of demand values, the corresponding scaling vector entries are always smaller.

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Foreground vs. Background Modelling</h2>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="pictures/electricity_showcase_4.png" alt="Image Alt Text" style="width: 50%;" />
# </div>

# %% [markdown]
# In this final part of the electricity showcase, the difference between foreground and background modelling and optimization is demonstrated. For that purpose a foreground system must be created ... this can be done either by hand or I can upload a folded foreground system for this case ... in essence, a new database must be created (e.g. "_cutoff38_foreground_" where copies from the market and electricity production activites are duplicated to from the "_cutoff38_". What this does is disconnecting this activities from their downstream.
#
# We are then replacing the original inputs in the electricity market with the duplicated processes from the foreground system, effectively disconnecting the choices made in the electricity market from the upstream of the electricity production technologies:

# %% [markdown]
# With this in mind, we can set up the optimization as usual, importing the "_cutoff38_foreground_" database instead of the "_cutoff38_" database:

# %%
project = "pulpo"
database = "cutoff38_foreground"

# %%
pulpo_worker = pulpo.PulpoOptimizer(project, database, methods, directory)

# %%
pulpo_worker.get_lci_data()

# %% [markdown]
# Now, choose the foreground market for electricity:

# %%
activities = ["market for electricity, high voltage, foreground"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

# %%
foreground_market = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
demand = {foreground_market[0]: 1.28819e+11}

# %% [markdown]
# And the foreground electricity production technologies:

# %%
activities = ["electricity production, lignite, foreground", 
             "electricity production, hard coal, foreground",
             "electricity production, nuclear, pressure water reactor, foreground",
             "electricity production, wind, 1-3MW turbine, onshore, foreground"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

electricity_activities = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
choices  = {'electricity': {electricity_activities[0]: 1e16,
                         electricity_activities[1]: 1e16,
                         electricity_activities[2]: 1e16,
                         electricity_activities[3]: 1e16}}

# %% [markdown]
# Create the instance and solve the problem:

# %%
instance = pulpo_worker.instantiate(choices=choices, demand=demand)
# Out:
# Creating Instance
# Instance created

# %%
results = pulpo_worker.solve(GAMS_PATH=GAMS_PATH)
# Out:
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         9.41 seconds required for presolve
# --- Job model.gms Start 12/10/23 11:00:07 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(143665) 38 Mb
# --- model.gms(144254) 43 Mb
# --- model.gms(269612) 65 Mb
# --- model.gms(269624) 65 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\cplex.opt
# --- model.gms(281420) 66 Mb
# --- model.gms(393612) 89 Mb
# --- Starting execution: elapsed 0:00:00.589
# --- model.gms(269623) 90 Mb
# --- Generating LP model GAMS_MODEL
# --- model.gms(137939) 102 Mb
# --- model.gms(143813) 109 Mb
# --- model.gms(191986) 125 Mb
# --- model.gms(269631) 128 Mb
# --- model.gms(269631) 127 Mb
# ---   82,618 rows  41,310 columns  676,679 non-zeroes
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:01.104
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 1.93 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 45.03 Mb (peak 45.34 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.73 Mb (peak 12.27 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 111216 rows and 28599 columns.
# Aggregator did 9388 substitutions.
# Reduced LP has 3320 rows, 3323 columns, and 100086 nonzeros.
# Presolve time = 0.38 sec. (919.26 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.555780
# Iteration:    86   Scaled dual infeas =            47.366384
# Iteration:   163   Scaled dual infeas =            44.360111
# Iteration:   246   Scaled dual infeas =            40.862054
# Iteration:   319   Scaled dual infeas =            39.881665
# Iteration:   394   Scaled dual infeas =            39.160475
# Iteration:   468   Scaled dual infeas =            38.609079
# Iteration:   548   Scaled dual infeas =            38.359321
# Iteration:   632   Scaled dual infeas =            34.627177
# Iteration:   709   Scaled dual infeas =            31.224183
# Iteration:   787   Scaled dual infeas =            30.844802
# Iteration:   865   Scaled dual infeas =            30.233704
# Iteration:   944   Scaled dual infeas =            27.167103
# Iteration:  1025   Scaled dual infeas =            26.802556
# Iteration:  1105   Scaled dual infeas =            26.394580
# Iteration:  1182   Scaled dual infeas =            25.809430
# Iteration:  1265   Scaled dual infeas =            23.866028
# Iteration:  1344   Scaled dual infeas =            17.045128
# Iteration:  1425   Scaled dual infeas =            13.535511
# Iteration:  1513   Scaled dual infeas =            11.415841
# Iteration:  1602   Scaled dual infeas =             9.761918
# Iteration:  1695   Scaled dual infeas =             9.086853
# Iteration:  1784   Scaled dual infeas =             7.752287
# Iteration:  1873   Scaled dual infeas =             7.096509
# Iteration:  1969   Scaled dual infeas =             4.799593
# Iteration:  2060   Scaled dual infeas =             3.513478
# Iteration:  2157   Scaled dual infeas =             2.877781
# Iteration:  2256   Scaled dual infeas =             2.382000
# Iteration:  2355   Scaled dual infeas =             2.052838
# Iteration:  2451   Scaled dual infeas =             1.245091
# Iteration:  2552   Scaled dual infeas =             1.009830
# Iteration:  2655   Scaled dual infeas =             0.394386
# Markowitz threshold set to 0.1
# Iteration:  2730   Scaled dual infeas =             0.000000
# Removing shift (51).
# Markowitz threshold set to 0.2
#
# --- LP status (1): optimal.
# --- Cplex Time: 2.49sec (det. 8836.08 ticks)
#
#
# Optimal solution found
# Objective:  17649658240.213589
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:03.718
# --- model.gms(269634) 127 Mb
# --- model.gms(393612) 127 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(393612) 124 Mb
# --- Job model.gms Stop 12/10/23 11:00:11 elapsed 0:00:03.904
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmpfm76rsg8
#
#         5.66 seconds required for solver
#         0.34 seconds required for postsolve
#        15.41 seconds required total

# %%
pulpo_worker.summarize_results(choices=choices, demand=demand, zeroes=True)
# Out:
# The following demand / functional unit has been specified:
#                                                                                          Demand
# market for electricity, high voltage, foreground | electricity, high voltage | DE  1.288190e+11
# These are the impacts contained in the objective:
#                                            Key         Value
# 0  ('IPCC 2013', 'climate change', 'GWP 100a')  1.764966e+10
# The following impacts were calculated:
#                                                        Key         Value
# 0              ('IPCC 2013', 'climate change', 'GWP 100a')  1.764966e+10
# 1       ('ReCiPe Endpoint (E,A)', 'human health', 'total')  2.927733e+09
# 3          ('ReCiPe Endpoint (E,A)', 'resources', 'total')  7.551099e+08
# 2  ('ReCiPe Endpoint (E,A)', 'ecosystem quality', 'total')  7.155927e+08
# The following choices were made:
# electricity
#                                                                                                      electricity  \
#                                                                                                         Activity
# Activity 0  electricity production, nuclear, pressure water reactor, foreground | electricity, high voltage | DE
#
#
#                 Capacity         Value
# Activity 0  1.000000e+16  8.153354e+10
# No additional constraints have been passed.

# %% [markdown]
# The result of this optimization is a minimum GWP of 1.764977e+10 kg CO2eq instead of 1.599836e+10 kg CO2eq from the initial calculations uising the full LCI. This is a difference of **8%**!

# %% [markdown]
# <div style="text-align: center; background-color: #f0f0f0; padding: 10px;">
#     <h2 style="font-family: 'Arial', sans-serif; font-weight: bold; color: #555;">Integer Cuts</h2>
# </div>

# %% [markdown]
# This functionality will be available in future versions of PULPO
