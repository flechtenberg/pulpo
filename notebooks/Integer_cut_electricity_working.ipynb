# %%
import os
import sys
sys.path.append('../')
from pulpo import pulpo

import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
project = "pulpo"
database = "cutoff38"
methods = "('IPCC 2013', 'climate change', 'GWP 100a')"

# Substitute with your working directory of choice
notebook_dir = os.path.dirname(os.getcwd())
directory = os.path.join(notebook_dir, 'data')

# Substitute with your GAMS path
GAMS_PATH = "C:/GAMS/37/gams.exe"

# %%
pulpo_worker = pulpo.PulpoOptimizer(project, database, methods, directory)

# %%
pulpo_worker.get_lci_data()

# %%
activities = ["market for electricity, high voltage"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

# %%
electricity_market = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
demand = {electricity_market[0]: 1}#1.28819e+11}

# %%
activities = ["electricity production, lignite", 
             "electricity production, hard coal",
             "electricity production, nuclear, pressure water reactor",
             "electricity production, wind, 1-3MW turbine, onshore"]
reference_products = ["electricity, high voltage"]
locations = ["DE"]

electricity_activities = pulpo_worker.retrieve_activities(activities=activities, reference_products=reference_products, locations=locations)

# %%
choices  = {'electricity': {electricity_activities[0]: 10,
                         electricity_activities[1]: 10,
                         electricity_activities[2]: 10,
                         electricity_activities[3]: 10}}

# %%
mip_bound = {'lower': 0.1,
             'upper': 4,
             'scale': 1e20}

# %%
instance = pulpo_worker.instantiate(choices=choices, demand=demand, mip_bound=mip_bound, initial=True)
results = pulpo_worker.solve(GAMS_PATH = GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         2.07 seconds required for presolve
# --- Job model.gms Start 10/23/23 12:02:59 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(95750) 28 Mb
# --- model.gms(125856) 33 Mb
# --- model.gms(137012) 35 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\cplex.opt
# --- model.gms(215345) 50 Mb
# --- Starting execution: elapsed 0:00:00.384
# --- model.gms(137011) 51 Mb
# --- Generating MIP model GAMS_MODEL
# --- model.gms(91449) 61 Mb
# --- model.gms(97854) 66 Mb
# --- model.gms(135612) 70 Mb
# --- model.gms(137019) 70 Mb
# ---   58,702 rows  19,571 columns  286,344 non-zeroes
# ---   4 discrete-columns
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:00.772
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 2.27 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 22.31 Mb (peak 22.46 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.05 Mb (peak 7.04 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Generic callback                                 0x50
# Tried aggregator 4 times.
# MIP Presolve eliminated 85118 rows and 6863 columns.
# MIP Presolve modified 19200 coefficients.
# Aggregator did 9506 substitutions.
# Reduced MIP has 3203 rows, 3202 columns, and 93941 nonzeros.
# Reduced MIP has 4 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.14 sec. (234.83 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 3203 rows, 3202 columns, and 93941 nonzeros.
# Reduced MIP has 4 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (26.97 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: none, using 1 thread.
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =           116.727195
# Iteration:    93   Scaled dual infeas =           106.460733
# Iteration:   189   Scaled dual infeas =            78.986261
# Iteration:   277   Scaled dual infeas =            74.283267
# Iteration:   352   Scaled dual infeas =            72.495482
# Iteration:   431   Scaled dual infeas =            71.700454
# Iteration:   519   Scaled dual infeas =            70.049788
# Iteration:   599   Scaled dual infeas =            68.772533
# Iteration:   685   Scaled dual infeas =            52.980925
# Iteration:   772   Scaled dual infeas =            47.807397
# Iteration:   851   Scaled dual infeas =            44.995303
# Iteration:   933   Scaled dual infeas =            38.142282
# Iteration:  1010   Scaled dual infeas =            34.365358
# Iteration:  1096   Scaled dual infeas =            30.264169
# Iteration:  1175   Scaled dual infeas =            23.060153
# Iteration:  1255   Scaled dual infeas =            22.016157
# Iteration:  1335   Scaled dual infeas =            17.303517
# Iteration:  1417   Scaled dual infeas =            14.115995
# Iteration:  1502   Scaled dual infeas =            12.544600
# Iteration:  1587   Scaled dual infeas =            10.351334
# Iteration:  1674   Scaled dual infeas =             8.122173
# Iteration:  1762   Scaled dual infeas =             6.784972
# Iteration:  1850   Scaled dual infeas =             5.095705
# Iteration:  1940   Scaled dual infeas =             4.253236
# Iteration:  2033   Scaled dual infeas =             3.772128
# Iteration:  2124   Scaled dual infeas =             1.740902
# Iteration:  2219   Scaled dual infeas =             1.346751
# Iteration:  2317   Scaled dual infeas =             0.926759
# Iteration:  2412   Scaled dual infeas =             0.625198
# Iteration:  2513   Scaled dual infeas =             0.231312
# Markowitz threshold set to 0.1
# Iteration:  2613   Scaled dual infeas =             0.076850
# Iteration:  2677   Scaled dual infeas =             0.000475
# Iteration:  2679   Scaled dual infeas =             0.000244
# Iteration:  2681   Scaled dual infeas =             0.000217
# Iteration:  2682   Scaled dual infeas =             0.000000
# Iteration:  2683   Dual objective     =             0.125885
# Removing shift (62).
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             0.125853
# Root relaxation solution time = 2.16 sec. (7532.97 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0     0      integral     0        0.1259        0.1259     2684    0.00%
# Elapsed time = 2.56 sec. (8561.27 ticks, tree = 0.00 MB)
# Found incumbent of value 0.125853 after 2.56 sec. (8561.27 ticks)
#
# Root node processing (before b&c):
#   Real time             =    2.56 sec. (8561.80 ticks)
# Sequential b&c:
#   Real time             =    0.00 sec. (0.00 ticks)
#                           ------------
# Total (root+branch&cut) =    2.56 sec. (8561.80 ticks)
#
# --- MIP status (101): integer optimal solution.
# --- Cplex Time: 2.56sec (det. 8561.86 ticks)
#
# --- Fixing integer variables and solving final LP...
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 2
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 85123 rows and 6867 columns.
# Aggregator did 9385 substitutions.
# Reduced LP has 3319 rows, 3319 columns, and 100019 nonzeros.
# Presolve time = 0.34 sec. (784.78 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.474670
# Iteration:    85   Scaled dual infeas =            47.357484
# Iteration:   161   Scaled dual infeas =            44.313980
# Iteration:   243   Scaled dual infeas =            40.820823
# Iteration:   317   Scaled dual infeas =            39.845583
# Iteration:   390   Scaled dual infeas =            39.133417
# Iteration:   465   Scaled dual infeas =            38.557988
# Iteration:   542   Scaled dual infeas =            38.295857
# Iteration:   622   Scaled dual infeas =            33.208598
# Iteration:   706   Scaled dual infeas =            31.076347
# Iteration:   788   Scaled dual infeas =            30.184279
# Iteration:   868   Scaled dual infeas =            28.130490
# Iteration:   942   Scaled dual infeas =            27.678420
# Iteration:  1021   Scaled dual infeas =            27.272485
# Iteration:  1101   Scaled dual infeas =            25.951314
# Iteration:  1180   Scaled dual infeas =            25.332346
# Iteration:  1263   Scaled dual infeas =            21.918228
# Iteration:  1347   Scaled dual infeas =            16.496029
# Iteration:  1431   Scaled dual infeas =            12.716259
# Iteration:  1519   Scaled dual infeas =            10.180112
# Iteration:  1606   Scaled dual infeas =             9.529554
# Iteration:  1696   Scaled dual infeas =             8.226381
# Iteration:  1786   Scaled dual infeas =             7.584886
# Iteration:  1875   Scaled dual infeas =             5.411122
# Iteration:  1969   Scaled dual infeas =             3.898276
# Iteration:  2064   Scaled dual infeas =             3.412754
# Iteration:  2157   Scaled dual infeas =             2.693036
# Iteration:  2257   Scaled dual infeas =             2.401466
# Iteration:  2353   Scaled dual infeas =             2.007757
# Iteration:  2454   Scaled dual infeas =             1.247558
# Iteration:  2555   Scaled dual infeas =             0.940498
# Iteration:  2657   Scaled dual infeas =             0.371558
# Markowitz threshold set to 0.1
# Iteration:  2719   Dual objective     =             0.125854
# Removing shift (46).
#
# --- Fixed MIP status (1): optimal.
# --- Cplex Time: 2.47sec (det. 8163.38 ticks)
#
#
# Proven optimal solution
# MIP Solution:            0.125853    (2684 iterations, 0 nodes)
# Final Solve:             0.126125    (2719 iterations)
#
# Best possible:           0.125853
# Absolute gap:            0.000000
# Relative gap:            0.000000
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:05.898
# --- model.gms(137022) 70 Mb
# --- model.gms(215345) 71 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(215345) 69 Mb
# --- Job model.gms Stop 10/23/23 12:03:05 elapsed 0:00:06.037
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmptcnmsan9
#
#         6.59 seconds required for solver
#         0.11 seconds required for postsolve
#         8.77 seconds required total

# %%
cuts = {'1': pulpo_worker.return_integer_cuts()}

# %%
instance = pulpo_worker.instantiate(choices=choices, demand=demand, mip_bound=mip_bound, cuts=cuts, initial=True)
results = pulpo_worker.solve(GAMS_PATH = GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         2.07 seconds required for presolve
# --- Job model.gms Start 10/23/23 12:03:11 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(96714) 28 Mb
# --- model.gms(135599) 34 Mb
# --- model.gms(137014) 35 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\cplex.opt
# --- model.gms(215348) 50 Mb
# --- Starting execution: elapsed 0:00:00.371
# --- model.gms(137013) 51 Mb
# --- Generating MIP model GAMS_MODEL
# --- model.gms(95829) 63 Mb
# --- model.gms(97856) 66 Mb
# --- model.gms(137021) 70 Mb
# ---   58,703 rows  19,571 columns  286,345 non-zeroes
# ---   4 discrete-columns
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:00.726
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 2.27 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 22.31 Mb (peak 22.46 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.05 Mb (peak 7.04 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Generic callback                                 0x50
# Tried aggregator 4 times.
# MIP Presolve eliminated 85124 rows and 6868 columns.
# MIP Presolve modified 19176 coefficients.
# Aggregator did 9504 substitutions.
# Reduced MIP has 3200 rows, 3199 columns, and 93904 nonzeros.
# Reduced MIP has 3 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.13 sec. (232.47 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 3200 rows, 3199 columns, and 93904 nonzeros.
# Reduced MIP has 3 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (26.96 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: none, using 1 thread.
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =           116.717516
# Iteration:    95   Scaled dual infeas =           106.076410
# Iteration:   190   Scaled dual infeas =            78.653897
# Iteration:   279   Scaled dual infeas =            72.504953
# Iteration:   358   Scaled dual infeas =            72.082180
# Iteration:   451   Scaled dual infeas =            71.114258
# Iteration:   540   Scaled dual infeas =            69.306623
# Iteration:   627   Scaled dual infeas =            55.825400
# Iteration:   719   Scaled dual infeas =            49.248255
# Iteration:   804   Scaled dual infeas =            45.196766
# Iteration:   888   Scaled dual infeas =            35.974037
# Iteration:   963   Scaled dual infeas =            32.421987
# Iteration:  1045   Scaled dual infeas =            30.505100
# Iteration:  1125   Scaled dual infeas =            27.562136
# Iteration:  1205   Scaled dual infeas =            24.921357
# Iteration:  1288   Scaled dual infeas =            20.087651
# Iteration:  1372   Scaled dual infeas =            16.138460
# Iteration:  1457   Scaled dual infeas =            13.464314
# Iteration:  1542   Scaled dual infeas =            12.282639
# Iteration:  1625   Scaled dual infeas =             8.300604
# Iteration:  1715   Scaled dual infeas =             7.383071
# Iteration:  1803   Scaled dual infeas =             6.262897
# Iteration:  1891   Scaled dual infeas =             5.197557
# Iteration:  1983   Scaled dual infeas =             3.642977
# Iteration:  2076   Scaled dual infeas =             2.111280
# Iteration:  2171   Scaled dual infeas =             1.617076
# Iteration:  2266   Scaled dual infeas =             1.218173
# Iteration:  2363   Scaled dual infeas =             0.783625
# Iteration:  2461   Scaled dual infeas =             0.385108
# Markowitz threshold set to 0.1
# Iteration:  2564   Scaled dual infeas =             0.122987
# Iteration:  2668   Scaled dual infeas =             0.002371
# Iteration:  2673   Scaled dual infeas =             0.000228
# Iteration:  2675   Scaled dual infeas =             0.000213
# Iteration:  2676   Scaled dual infeas =             0.000469
# Iteration:  2677   Scaled dual infeas =             0.000270
# Iteration:  2678   Scaled dual infeas =             0.000219
# Iteration:  2679   Scaled dual infeas =             0.000000
# Iteration:  2680   Dual objective     =             0.134672
# Removing shift (48).
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             0.134737
# Root relaxation solution time = 2.30 sec. (8499.78 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0     0      integral     0        0.1347        0.1347     2681    0.00%
# Elapsed time = 2.64 sec. (9525.23 ticks, tree = 0.00 MB)
# Found incumbent of value 0.134737 after 2.64 sec. (9525.23 ticks)
#
# Root node processing (before b&c):
#   Real time             =    2.66 sec. (9525.77 ticks)
# Sequential b&c:
#   Real time             =    0.00 sec. (0.00 ticks)
#                           ------------
# Total (root+branch&cut) =    2.66 sec. (9525.77 ticks)
#
# --- MIP status (101): integer optimal solution.
# --- Cplex Time: 2.66sec (det. 9525.83 ticks)
#
# --- Fixing integer variables and solving final LP...
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 2
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 85127 rows and 6870 columns.
# Aggregator did 9383 substitutions.
# Reduced LP has 3318 rows, 3318 columns, and 99976 nonzeros.
# Presolve time = 0.33 sec. (783.70 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.451010
# Iteration:    88   Scaled dual infeas =            47.349005
# Iteration:   174   Scaled dual infeas =            41.714731
# Iteration:   254   Scaled dual infeas =            40.835396
# Iteration:   325   Scaled dual infeas =            39.212415
# Iteration:   399   Scaled dual infeas =            39.005157
# Iteration:   475   Scaled dual infeas =            38.490710
# Iteration:   560   Scaled dual infeas =            38.255491
# Iteration:   639   Scaled dual infeas =            33.172165
# Iteration:   719   Scaled dual infeas =            31.004455
# Iteration:   796   Scaled dual infeas =            29.900905
# Iteration:   876   Scaled dual infeas =            27.828582
# Iteration:   952   Scaled dual infeas =            27.006304
# Iteration:  1030   Scaled dual infeas =            26.059987
# Iteration:  1115   Scaled dual infeas =            25.541836
# Iteration:  1193   Scaled dual infeas =            24.781845
# Iteration:  1278   Scaled dual infeas =            16.531175
# Iteration:  1361   Scaled dual infeas =            13.355579
# Iteration:  1441   Scaled dual infeas =            12.364178
# Iteration:  1531   Scaled dual infeas =            10.513366
# Iteration:  1616   Scaled dual infeas =             9.444405
# Iteration:  1704   Scaled dual infeas =             9.209069
# Iteration:  1795   Scaled dual infeas =             7.937832
# Iteration:  1881   Scaled dual infeas =             7.385136
# Iteration:  1979   Scaled dual infeas =             4.957736
# Iteration:  2071   Scaled dual infeas =             3.508915
# Iteration:  2167   Scaled dual infeas =             2.579234
# Iteration:  2266   Scaled dual infeas =             2.294034
# Iteration:  2362   Scaled dual infeas =             2.034300
# Iteration:  2465   Scaled dual infeas =             1.244558
# Iteration:  2567   Scaled dual infeas =             0.888759
# Iteration:  2671   Scaled dual infeas =             0.153772
# Markowitz threshold set to 0.1
# Iteration:  2719   Dual objective     =             0.134740
# Removing shift (44).
#
# --- Fixed MIP status (1): optimal.
# --- Cplex Time: 2.47sec (det. 8224.77 ticks)
#
#
# Proven optimal solution
# MIP Solution:            0.134737    (2681 iterations, 0 nodes)
# Final Solve:             0.135014    (2719 iterations)
#
# Best possible:           0.134737
# Absolute gap:            0.000000
# Relative gap:            0.000000
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:05.915
# --- model.gms(137024) 70 Mb
# --- model.gms(215348) 71 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(215348) 69 Mb
# --- Job model.gms Stop 10/23/23 12:03:17 elapsed 0:00:06.050
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmp8n_4jg50
#
#         7.01 seconds required for solver
#         0.11 seconds required for postsolve
#         9.19 seconds required total

# %%
cuts['2'] = pulpo_worker.return_integer_cuts()

# %%
instance = pulpo_worker.instantiate(choices=choices, demand=demand, mip_bound=mip_bound, cuts=cuts, initial=True)
results = pulpo_worker.solve(GAMS_PATH = GAMS_PATH)
# Out:
# Creating Instance
# Instance created
# GAMS solvers library availability: True
# Solver path: C:\GAMS\37\gams.exe
#         2.10 seconds required for presolve
# --- Job model.gms Start 10/23/23 12:03:34 37.1.0 r07954d5 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\GAMS\37\gmsprmNT.txt
#     C:\Users\Usuario\Documents\GAMS\gamsconfig.yaml
# --- GAMS Parameters defined
#     MIP CPLEX
#     Input C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\model.gms
#     Output C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\output.lst
#     ScrDir C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\225a\
#     SysDir C:\GAMS\37\
#     CurDir C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\
#     LogOption 3
#     OptCR 1E-9
# Licensee: Antonio Espuna, Single User License            S210319|0002AN-WIN
#           Universitat Politecnica de Catalunya, Chemical Engineering DC6757
#           C:\Users\Usuario\Documents\GAMS\gamslice.txt
#           antonio.espuna@upc.edu
# Processor information: 1 socket(s), 12 core(s), and 20 thread(s) available
# GAMS 37.1.0   Copyright (C) 1987-2021 GAMS Development. All rights reserved
# --- Starting compilation
# --- model.gms(96550) 28 Mb
# --- model.gms(136088) 34 Mb
# --- model.gms(137016) 35 Mb
# --- $echo File C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\cplex.opt
# --- model.gms(215351) 50 Mb
# --- Starting execution: elapsed 0:00:00.370
# --- model.gms(137015) 51 Mb
# --- Generating MIP model GAMS_MODEL
# --- model.gms(94059) 62 Mb
# --- model.gms(97858) 66 Mb
# --- model.gms(137023) 70 Mb
# ---   58,704 rows  19,571 columns  286,346 non-zeroes
# ---   4 discrete-columns
# --- Executing CPLEX (Solvelink=5): elapsed 0:00:00.748
#
# IBM ILOG CPLEX   37.1.0 r07954d5 Released Nov 11, 2021 WEI x86 64bit/MS Window
#
# --- GAMS/Cplex Link licensed for continuous and discrete problems.
#
# Reading parameter(s) from "C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\cplex.opt"
# >>  workmem=4096
# >>  scaind=1
# Finished reading from "C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 2.27 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 22.31 Mb (peak 22.46 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 20.1.0.1 link memory 1.05 Mb (peak 7.04 Mb)
# --- Starting Cplex
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 0
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Generic callback                                 0x50
# Tried aggregator 4 times.
# MIP Presolve eliminated 85127 rows and 6870 columns.
# MIP Presolve modified 19201 coefficients.
# Aggregator did 9504 substitutions.
# Reduced MIP has 3198 rows, 3197 columns, and 93889 nonzeros.
# Reduced MIP has 2 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.16 sec. (233.17 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 3198 rows, 3197 columns, and 93889 nonzeros.
# Reduced MIP has 2 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (26.95 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: none, using 1 thread.
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =           116.727958
# Iteration:    90   Scaled dual infeas =           110.271303
# Iteration:   179   Scaled dual infeas =            97.381600
# Iteration:   268   Scaled dual infeas =            74.402414
# Iteration:   345   Scaled dual infeas =            72.502217
# Iteration:   428   Scaled dual infeas =            71.528466
# Iteration:   516   Scaled dual infeas =            69.844561
# Iteration:   598   Scaled dual infeas =            61.176386
# Iteration:   689   Scaled dual infeas =            52.300730
# Iteration:   771   Scaled dual infeas =            47.594246
# Iteration:   851   Scaled dual infeas =            43.716890
# Iteration:   931   Scaled dual infeas =            36.527664
# Iteration:  1011   Scaled dual infeas =            35.448593
# Iteration:  1094   Scaled dual infeas =            23.119836
# Iteration:  1172   Scaled dual infeas =            22.638479
# Iteration:  1248   Scaled dual infeas =            21.516523
# Iteration:  1331   Scaled dual infeas =            15.722890
# Iteration:  1410   Scaled dual infeas =            13.564229
# Iteration:  1496   Scaled dual infeas =            12.094969
# Iteration:  1579   Scaled dual infeas =            10.478144
# Iteration:  1667   Scaled dual infeas =             9.673454
# Iteration:  1752   Scaled dual infeas =             7.140594
# Iteration:  1840   Scaled dual infeas =             6.052881
# Iteration:  1929   Scaled dual infeas =             4.319569
# Iteration:  2021   Scaled dual infeas =             2.414402
# Markowitz threshold set to 0.1
# Iteration:  2116   Scaled dual infeas =             1.750261
# Iteration:  2213   Scaled dual infeas =             1.375647
# Iteration:  2311   Scaled dual infeas =             0.923046
# Iteration:  2409   Scaled dual infeas =             0.500168
# Iteration:  2508   Scaled dual infeas =             0.267700
# Iteration:  2612   Scaled dual infeas =             0.046769
# Iteration:  2670   Scaled dual infeas =             0.000272
# Iteration:  2672   Scaled dual infeas =             0.000220
# Iteration:  2673   Scaled dual infeas =             0.000469
# Iteration:  2674   Scaled dual infeas =             0.000269
# Iteration:  2675   Scaled dual infeas =             0.000219
# Iteration:  2676   Scaled dual infeas =             0.000000
# Iteration:  2677   Dual objective     =             0.803760
# Removing shift (51).
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             0.803819
# Root relaxation solution time = 2.28 sec. (8416.57 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0     0      integral     0        0.8038        0.8038     2678    0.00%
# Elapsed time = 2.69 sec. (9439.27 ticks, tree = 0.00 MB)
# Found incumbent of value 0.803819 after 2.69 sec. (9439.27 ticks)
#
# Root node processing (before b&c):
#   Real time             =    2.69 sec. (9439.80 ticks)
# Sequential b&c:
#   Real time             =    0.00 sec. (0.00 ticks)
#                           ------------
# Total (root+branch&cut) =    2.69 sec. (9439.80 ticks)
#
# --- MIP status (101): integer optimal solution.
# --- Cplex Time: 2.69sec (det. 9439.86 ticks)
#
# --- Fixing integer variables and solving final LP...
#
# Version identifier: 20.1.0.1 | 2021-04-07 | 3a818710c
# CPXPARAM_Advance                                 2
# CPXPARAM_Read_Scale                              1
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_TimeLimit                               3600
# CPXPARAM_WorkMem                                 4096
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   1.0000000000000001e-15
# Tried aggregator 1 time.
# Linear dependency checker was stopped due to maximum work limit.
# LP Presolve eliminated 85128 rows and 6870 columns.
# Aggregator did 9383 substitutions.
# Reduced LP has 3318 rows, 3318 columns, and 99981 nonzeros.
# Presolve time = 0.36 sec. (783.44 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Scaled dual infeas =            50.451010
# Iteration:    88   Scaled dual infeas =            47.394034
# Iteration:   174   Scaled dual infeas =            41.772551
# Iteration:   254   Scaled dual infeas =            40.906782
# Iteration:   326   Scaled dual infeas =            39.297093
# Iteration:   399   Scaled dual infeas =            39.069566
# Iteration:   474   Scaled dual infeas =            38.105970
# Iteration:   556   Scaled dual infeas =            37.527649
# Iteration:   640   Scaled dual infeas =            31.273932
# Iteration:   721   Scaled dual infeas =            30.593141
# Iteration:   798   Scaled dual infeas =            29.387741
# Iteration:   879   Scaled dual infeas =            29.081246
# Iteration:   957   Scaled dual infeas =            27.756782
# Iteration:  1036   Scaled dual infeas =            27.242033
# Iteration:  1111   Scaled dual infeas =            25.851474
# Iteration:  1186   Scaled dual infeas =            25.268451
# Iteration:  1269   Scaled dual infeas =            24.213264
# Iteration:  1352   Scaled dual infeas =            16.378127
# Iteration:  1431   Scaled dual infeas =            12.798497
# Iteration:  1517   Scaled dual infeas =            10.917633
# Iteration:  1608   Scaled dual infeas =             9.615636
# Iteration:  1698   Scaled dual infeas =             9.363641
# Iteration:  1787   Scaled dual infeas =             8.063352
# Iteration:  1876   Scaled dual infeas =             7.296326
# Iteration:  1972   Scaled dual infeas =             5.044914
# Iteration:  2065   Scaled dual infeas =             3.342678
# Iteration:  2163   Scaled dual infeas =             2.716506
# Iteration:  2260   Scaled dual infeas =             2.355276
# Iteration:  2362   Scaled dual infeas =             2.065091
# Iteration:  2463   Scaled dual infeas =             1.244299
# Iteration:  2566   Scaled dual infeas =             0.939880
# Iteration:  2667   Scaled dual infeas =             0.315396
# Markowitz threshold set to 0.1
# Iteration:  2722   Dual objective     =             0.803822
# Removing shift (37).
#
# --- Fixed MIP status (1): optimal.
# --- Cplex Time: 2.50sec (det. 8279.44 ticks)
#
#
# Proven optimal solution
# MIP Solution:            0.803819    (2678 iterations, 0 nodes)
# Final Solve:             0.804321    (2722 iterations)
#
# Best possible:           0.803819
# Absolute gap:            0.000000
# Relative gap:            0.000000
#
# --- Reading solution for model GAMS_MODEL
# --- Executing after solve: elapsed 0:00:06.014
# --- model.gms(137026) 70 Mb
# --- model.gms(215351) 71 Mb
# --- Putfile results C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\results.dat
# --- Putfile statresults C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev\resultsstat.dat
# *** Status: Normal completion
# --- model.gms(215351) 69 Mb
# --- Job model.gms Stop 10/23/23 12:03:41 elapsed 0:00:06.148
#
# GAMS WORKING DIRECTORY: C:\Users\Usuario\AppData\Local\Temp\tmpcw8rspev
#
#         7.11 seconds required for solver
#         0.12 seconds required for postsolve
#         9.33 seconds required total
